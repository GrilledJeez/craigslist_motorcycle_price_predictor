# %%
#import get to call a get request on the site
import requests

#import to manipulate arrays with numpy
import numpy as np

#import to create, clean, and parse data frames with pandas
import pandas as pd

#import to enable datascraping
from bs4 import BeautifulSoup

#import to set up 'sleep' to wait between page loads
import time

#import to make that html readable
import pprint

#import regular expressions operations
import re

#import to get the universe in balance
import random

#import so we can do some heavy stats work
import scipy as sp
from scipy.stats import binom
import scipy.stats as stats

#import to access certain plotting features
import seaborn as sns

#import because we need its program functions
import math

#import because we need to plot and make it pretty
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
# %matplotlib inline
plt.style.use('ggplot')

# %%
response = requests.get('https://austin.craigslist.org/search/mca?s=0&bundleDuplicates=1')

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')

posts = html_soup.find_all('li', class_= 'result-row')
print(type(posts)) #to double check that I got a ResultSet
print(len(posts)) #to double check I got 120 (elements/page)
# Out:
# <class 'bs4.element.ResultSet'>
# 124

# %%
pprint.pprint(response.text)
# Out:
# ('\ufeff<!DOCTYPE html>\n'
#  '<html class="no-js"><head>\n'
#  '    <title>austin motorcycles/scooters  - craigslist</title>\n'
#  '\n'
#  '    <meta name="description" content="austin motorcycles/scooters  - '
#  'craigslist">\n'
#  '    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n'
#  '    <link rel="canonical" href="https://austin.craigslist.org/search/mca">\n'
#  '    <link rel="alternate" type="application/rss+xml" '
#  'href="https://austin.craigslist.org/search/mca?bundleDuplicates=1&amp;format=rss" '
#  'title="RSS feed for craigslist | austin motorcycles/scooters  - '
#  'craigslist">\n'
#  '        <link rel="next" '
#  'href="https://austin.craigslist.org/search/mca?s=120&amp;bundleDuplicates=1">\n'
#  '    <meta name="viewport" content="width=device-width,initial-scale=1">\n'
#  '    <link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/cl.css?v=784f71fcd82733e2b32e8d3284beaf58">\n'
#  '    <link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b">\n'
#  '    <link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n'
#  '<link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n'
#  '<link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n'
#  '<link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n'
#  '<!--[if IE]>\n'
#  '    <link type="text/css" rel="stylesheet" media="all" '
#  'href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n'
#  '<![endif]-->\n'
#  '\n'
#  '    \n'
#  '        <script type="text/javascript"><!--\n'
#  'var areaCountry = "US";\n'
#  'var areaID = "15";\n'
#  'var areaRegion = "TX";\n'
#  'var catAbb = "mca";\n'
#  'var countOfTotalText = "image {count} of {total}";\n'
#  'var currencySymbol = "&#x0024;";\n'
#  'var defaultView = "grid";\n'
#  'var expiredFavIDs = null;\n'
#  'var imageConfig = '
#  '{"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\n'
#  'var lessInfoText = "less info";\n'
#  'var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\n'
#  'var maxResults = 3000;\n'
#  'var noImageText = "no image";\n'
#  'var pID = null;\n'
#  'var postalLat = null;\n'
#  'var postalLon = null;\n'
#  'var purveyorCategories = {"owner":"mcy","dealer":"mcd","all":"mca"};\n'
#  'var searchDistance = null;\n'
#  'var sectionAbb = "sss";\n'
#  'var sectionBase = "sss";\n'
#  'var showInfoText = "show info";\n'
#  'var showMapTabs = 1;\n'
#  'var showingBanished = 0;\n'
#  'var showingFavorites = 0;\n'
#  'var starHint = "save this post in your favorites list";\n'
#  'var subarea = null;\n'
#  'var zoomToPosting = null;\n'
#  '--></script>\n'
#  '    \n'
#  '</head>\n'
#  '<body class="search has-map">\n'
#  '    <script type="text/javascript"><!--\n'
#  "    function C(k){return(document.cookie.match('(^|; "
#  ")'+k+'=([^;]*)')||0)[2]}\n"
#  '    var pagetype, pagemode;\n'
#  '    (function(){\n'
#  '        var h = document.documentElement;\n'
#  "        h.className = h.className.replace('no-js', 'js');\n"
#  '        var b = document.body;\n'
#  '        var bodyClassList = b.className.split(/\\s+/);;\n'
#  '        pagetype = bodyClassList[0]; // dangerous assumption\n'
#  "        var fmt = C('cl_fmt');\n"
#  "        if ( fmt === 'regular' || fmt === 'mobile' ) {\n"
#  '            pagemode = fmt;\n'
#  '        } else if (screen.width <= 480) {\n'
#  "            pagemode = 'mobile';\n"
#  '        } else {\n'
#  "            pagemode = 'regular';\n"
#  '        }\n'
#  "        pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';\n"
#  '        bodyClassList.push(pagemode);\n'
#  "        if (C('hidesearch') === '1' && pagemode !== 'mobile') {\n"
#  "            bodyClassList.push('hide-search');\n"
#  '        }\n'
#  '        var width = window.innerWidth || '
#  'document.documentElement.clientWidth;\n'
#  "        if (width > 1000) { bodyClassList.push('w1024'); }\n"
#  "        if (typeof window.sectionBase !== 'undefined') {\n"
#  "            var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new "
#  "RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || "
#  'window.defaultView;\n'
#  '            if (mode) {\n'
#  '                bodyClassList.push(mode);\n'
#  '            }\n'
#  '        }\n'
#  "        b.className = bodyClassList.join(' ');\n"
#  '    }());\n'
#  '--></script>\n'
#  '\n'
#  '\n'
#  '    <section class="page-container" id="page-top">\n'
#  '        <div class="bglogo"></div>\n'
#  '        <div class="tryapp">\n'
#  '    try the craigslist app &raquo;\n'
#  '    <a class="appstorebtn"\n'
#  '    '
#  'href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">\n'
#  '        Android\n'
#  '    </a>\n'
#  '    <a class="appstorebtn"\n'
#  '    href="https://apps.apple.com/us/app/craigslist/id1336642410">\n'
#  '        iOS\n'
#  '    </a>\n'
#  '</div>\n'
#  '<header class="global-header wide">\n'
#  '   <a class="header-logo" name="logoLink" href="/">CL</a>\n'
#  '\n'
#  '    <nav class="breadcrumbs-container">\n'
#  '<form id="breadcrumbform" class="breadcrumbs-form" method="get" '
#  'action="/search/mca" data-action="/search/###/mca">\n'
#  '    <input type="hidden" name="bundleDuplicates" value="1">\n'
#  '\n'
#  '    <ul class="breadcrumbs ">\n'
#  '        <li class="crumb area">\n'
#  '            \n'
#  '            <span class="no-js">\n'
#  '                <a href="/">austin</a>\n'
#  '            </span>\n'
#  '                <select name="areaAbb" id="areaAbb" class="js-only">\n'
#  '                    <option value="austin">austin</option>\n'
#  '                        <option value="abilene">abilene</option>\n'
#  '                        <option value="beaumont">beaumont</option>\n'
#  '                        <option value="collegestation">college '
#  'station</option>\n'
#  '                        <option value="corpuschristi">corpus '
#  'christi</option>\n'
#  '                        <option value="dallas">dallas</option>\n'
#  '                        <option value="nacogdoches">deep east TX</option>\n'
#  '                        <option value="delrio">del rio</option>\n'
#  '                        <option value="easttexas">east TX</option>\n'
#  '                        <option value="galveston">galveston</option>\n'
#  '                        <option value="houston">houston</option>\n'
#  '                        <option value="killeen">killeen-temple</option>\n'
#  '                        <option value="laredo">laredo</option>\n'
#  '                        <option value="sanangelo">san angelo</option>\n'
#  '                        <option value="sanantonio">san antonio</option>\n'
#  '                        <option value="sanmarcos">san marcos</option>\n'
#  '                        <option value="victoriatx">victoria, TX</option>\n'
#  '                        <option value="waco">waco</option>\n'
#  '                </select>\n'
#  '            <span class="breadcrumb-arrow">&gt;</span>\n'
#  '        </li>\n'
#  '        <li class="crumb section">\n'
#  '                    <select name="catAbb" id="catAbb">\n'
#  '                        <option value="ccc">community</option>\n'
#  '                        <option value="eee">events</option>\n'
#  '                        <option value="sss" selected>for sale</option>\n'
#  '                        <option value="ggg">gigs</option>\n'
#  '                        <option value="hhh">housing</option>\n'
#  '                        <option value="jjj">jobs</option>\n'
#  '                        <option value="rrr">resumes</option>\n'
#  '                        <option value="bbb">services</option>\n'
#  '                    </select>\n'
#  '                <span class="breadcrumb-arrow">&gt;</span>\n'
#  '        </li>\n'
#  '        <li class="crumb category">\n'
#  '            <select id="subcatAbb" class="js-only">\n'
#  '                <option value="sss">all</option>\n'
#  '                    <option value="ata">antiques</option>\n'
#  '                    <option value="ppa">appliances</option>\n'
#  '                    <option value="ara">arts+crafts</option>\n'
#  '                    <option value="sna">atvs/utvs/snow</option>\n'
#  '                    <option value="pta">auto parts</option>\n'
#  '                    <option value="wta">auto wheels &amp; tires</option>\n'
#  '                    <option value="ava">aviation</option>\n'
#  '                    <option value="baa">baby+kids</option>\n'
#  '                    <option value="bar">barter</option>\n'
#  '                    <option value="haa">beauty+hlth</option>\n'
#  '                    <option value="bip">bike parts</option>\n'
#  '                    <option value="bia">bikes</option>\n'
#  '                    <option value="bpa">boat parts</option>\n'
#  '                    <option value="boo">boats</option>\n'
#  '                    <option value="bka">books</option>\n'
#  '                    <option value="bfa">business</option>\n'
#  '                    <option value="cta">cars+trucks</option>\n'
#  '                    <option value="ema">cds/dvd/vhs</option>\n'
#  '                    <option value="moa">cell phones</option>\n'
#  '                    <option value="cla">clothes+acc</option>\n'
#  '                    <option value="cba">collectibles</option>\n'
#  '                    <option value="syp">computer parts</option>\n'
#  '                    <option value="sya">computers</option>\n'
#  '                    <option value="ela">electronics</option>\n'
#  '                    <option value="gra">farm+garden</option>\n'
#  '                    <option value="zip">free stuff</option>\n'
#  '                    <option value="fua">furniture</option>\n'
#  '                    <option value="gms">garage sales</option>\n'
#  '                    <option value="foa">general</option>\n'
#  '                    <option value="hva">heavy equipment</option>\n'
#  '                    <option value="hsa">household</option>\n'
#  '                    <option value="jwa">jewelry</option>\n'
#  '                    <option value="maa">materials</option>\n'
#  '                    <option value="mpa">motorcycle parts</option>\n'
#  '                    <option value="mca" selected>motorcycles</option>\n'
#  '                    <option value="msa">music instr</option>\n'
#  '                    <option value="pha">photo+video</option>\n'
#  '                    <option value="rva">RVs</option>\n'
#  '                    <option value="sga">sporting</option>\n'
#  '                    <option value="tia">tickets</option>\n'
#  '                    <option value="tla">tools</option>\n'
#  '                    <option value="taa">toys+games</option>\n'
#  '                    <option value="tra">trailers</option>\n'
#  '                    <option value="vga">video gaming</option>\n'
#  '                    <option value="waa">wanted</option>\n'
#  '            </select><span class="no-js">motorcycles</span>\n'
#  '            <span class="breadcrumb-arrow">&gt;</span>\n'
#  '        </li>\n'
#  '        <li class="crumb no-js">\n'
#  '            <input type="submit" value="go">\n'
#  '        </li>\n'
#  '    </ul>\n'
#  '</form>\n'
#  '    </nav>\n'
#  '\n'
#  '<div class="userlinks">\n'
#  '    <ul class="user-actions">\n'
#  '        <li class="user post">\n'
#  '            <a href="https://post.craigslist.org/c/aus">post</a>\n'
#  '        </li>\n'
#  '        <li class="user account">\n'
#  '            <a '
#  'href="https://accounts.craigslist.org/login/home">account</a>\n'
#  '        </li>\n'
#  '    </ul>\n'
#  '    <ul class="user-favs-discards">\n'
#  '        <li class="user">\n'
#  '            <div class="favorites">\n'
#  '                <a href="#" class="favlink"><span class="icon icon-star fav" '
#  'aria-hidden="true"></span><span class="fav-number">0</span><span '
#  'class="fav-label"> favorites</span></a>\n'
#  '            </div>\n'
#  '        </li>\n'
#  '        <li class="user discards">\n'
#  '          <form class="unfavform js-only" method="POST" '
#  'action="/favorites">\n'
#  '            <div class="to-banish-page">\n'
#  '              <input type="hidden" class="lastLink" name="lastLink" '
#  'value="//austin.craigslist.org/search/mca?bundleDuplicates=1">\n'
#  '              <input type="hidden" class="lastTitle" name="lastTitle" '
#  'value="">\n'
#  '              <input type="hidden" class="unfaves" name="fl">\n'
#  '              <input type="hidden" name="uf" value="1">\n'
#  '              <a href="#" class="to-banish-page-link">\n'
#  '                <span class="icon icon-trash red" '
#  'aria-hidden="true"></span>\n'
#  '                <span class="banished_count">0</span>\n'
#  '                <span class="discards-label"> hidden</span>\n'
#  '              </a>\n'
#  '            </div>\n'
#  '          </form>\n'
#  '        </li>\n'
#  '    </ul>\n'
#  '</div>\n'
#  '\n'
#  '</header>\n'
#  '<header class="global-header narrow">\n'
#  '   <a class="header-logo" href="/">CL</a>\n'
#  '    <nav class="breadcrumbs-container">\n'
#  '\n'
#  '<ul class="breadcrumbs">\n'
#  '\n'
#  '\n'
#  'austin            &gt;\n'
#  '\n'
#  'motorcycles/scooters\n'
#  '\n'
#  '</ul>\n'
#  '\n'
#  '\n'
#  '    </nav>\n'
#  '    <span class="linklike show-wide-header">...</span>\n'
#  '</header>\n'
#  '\n'
#  '\n'
#  '        <form id="searchform" class="search-form" action="/search/mca">\n'
#  '            <div class="querybox">\n'
#  '                \n'
#  '                <div class="form-tab js-only"><span class="search-open" '
#  'title="hide search">&laquo;</span><span class="search-closed" title="show '
#  'search">&raquo;</span></div>\n'
#  '                <input type="text" placeholder="search motorcycles/scooters" '
#  'name="query"\n'
#  '                    id="query" value="" autocorrect="off" class="flatinput '
#  'ui-autocomplete-input"\n'
#  '                    autocapitalize="off" autocomplete="off" '
#  'data-autocomplete="search">\n'
#  '\n'
#  '                <button type="submit" class="searchbtn">\n'
#  '                    <span class="icon icon-search" '
#  'aria-hidden="true"></span>\n'
#  '                    <span class="screen-reader-text">press to search '
#  'craigslist</span>\n'
#  '                </button>\n'
#  '                    <div class="savealert">\n'
#  '                        <a class="saveme" data-action="save"  '
#  'href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Faustin%252Ecraigslist%252Eorg%252Fsearch%252Fmca%253FbundleDuplicates%253D1"  '
#  'title="save this search" >save search</a>\n'
#  '                    </div>\n'
#  '            </div>\n'
#  '\n'
#  '            <div class="search-options-container">\n'
#  '    <h2 class="search-options-header linklike">\n'
#  '        <div class="icon icon-toggle-gear" aria-hidden="true"></div>\n'
#  '        options<span class="options-close">close</span>\n'
#  '    </h2>\n'
#  '    <input id="excats" type="hidden" name="excats">\n'
#  '    <div class="search-options">\n'
#  '        <div class="searchgroup categories">\n'
#  '            <div class="cattitle">\n'
#  '                  <a href="/search/mca" title="clear all search parameters" '
#  'class="reset">motorcycles/scooters</a>\n'
#  '            </div>\n'
#  '\n'
#  '        </div>\n'
#  '        <input type="hidden" name="userid" value="" />\n'
#  '\n'
#  '                <ul class="searchgroup buttongroup purveyor">\n'
#  '                    <li class="button sel">\n'
#  '                        <a href="/search/mca?bundleDuplicates=1" '
#  'data-val="all">all</a>\n'
#  '                    </li><li class="button ">\n'
#  '                        <a href="/search/mcy?bundleDuplicates=1" '
#  'data-val="owner"> owner</a>\n'
#  '                    </li><li class="button ">\n'
#  '                        <a href="/search/mcd?bundleDuplicates=1" '
#  'data-val="dealer">dealer</a>\n'
#  '                    </li>\n'
#  '                </ul>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '        <div class="searchgroup">\n'
#  '            <ul>\n'
#  '    <li>\n'
#  '       <label class="srchType">\n'
#  '           <input type="checkbox" name="srchType" class="" value="T" >\n'
#  '           search titles only\n'
#  '       </label>\n'
#  '    </li>\n'
#  '    <li>\n'
#  '       <label class="hasPic">\n'
#  '           <input type="checkbox" name="hasPic" class="autosubmit" value="1" '
#  '>\n'
#  '           has image\n'
#  '       </label>\n'
#  '    </li>\n'
#  '    <li>\n'
#  '       <label class="postedToday">\n'
#  '           <input type="checkbox" name="postedToday" class="autosubmit" '
#  'value="1" >\n'
#  '           posted today\n'
#  '       </label>\n'
#  '    </li>\n'
#  '    <li>\n'
#  '       <label class="bundleDuplicates">\n'
#  '           <input type="checkbox" name="bundleDuplicates" class="autosubmit" '
#  'value="1"  checked>\n'
#  '           bundle duplicates\n'
#  '       </label>\n'
#  '    </li>\n'
#  '    <li>\n'
#  '       <label class="searchNearby">\n'
#  '           <input type="checkbox" name="searchNearby" class="autosubmit" '
#  'value="1" >\n'
#  '           include nearby areas\n'
#  '       </label>\n'
#  '    </li>\n'
#  '</ul>\n'
#  '\n'
#  '                <ul class="js-only nearbyAreas ">\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_11"\n'
#  '                            value="364"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            abilene, TX <small>(abi)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_15"\n'
#  '                            value="264"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            beaumont / port arthur <small>(bpt)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_23"\n'
#  '                            value="266"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            brownsville, TX <small>(bro)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_3"\n'
#  '                            value="326"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            college station, TX <small>(cst)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_7"\n'
#  '                            value="265"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            corpus christi, TX <small>(crp)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_9"\n'
#  '                            value="21"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            dallas / fort worth <small>(dal)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_14"\n'
#  '                            value="645"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            deep east texas <small>(och)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_12"\n'
#  '                            value="647"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            del rio / eagle pass <small>(drt)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_10"\n'
#  '                            value="470"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            galveston, TX <small>(gls)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_6"\n'
#  '                            value="23"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            houston, TX <small>(hou)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_1"\n'
#  '                            value="327"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            killeen / temple / ft hood <small>(grk)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_19"\n'
#  '                            value="284"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            lake charles, LA <small>(lkc)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_16"\n'
#  '                            value="271"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            laredo, TX <small>(lrd)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_4">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_24"\n'
#  '                            value="422"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            lawton, OK <small>(law)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_21"\n'
#  '                            value="263"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            mcallen / edinburg <small>(mca)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_22"\n'
#  '                            value="268"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            odessa / midland <small>(odm)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_1">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_8"\n'
#  '                            value="646"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            san angelo, TX <small>(sjt)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_2"\n'
#  '                            value="53"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            san antonio <small>(sat)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_0"\n'
#  '                            value="449"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            san marcos, TX <small>(tsu)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_20"\n'
#  '                            value="206"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            shreveport, LA <small>(shv)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_4">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_25"\n'
#  '                            value="359"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            texarkana <small>(txk)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_17"\n'
#  '                            value="649"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            texoma <small>(txm)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_2">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_13"\n'
#  '                            value="308"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            tyler / east TX <small>(etx)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_5"\n'
#  '                            value="564"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            victoria, TX <small>(vtx)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_4"\n'
#  '                            value="270"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            waco, TX <small>(wco)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '                        <li class="nearbyZone nearbyZone_3">\n'
#  '                        <label class="nearby">\n'
#  '                            <input\n'
#  '                            type="checkbox"\n'
#  '                            class="use-id nearbyArea"\n'
#  '                            name="nearbyArea"\n'
#  '                            id="nearbyArea_18"\n'
#  '                            value="365"\n'
#  '                            disabled="disabled"\n'
#  '                            />\n'
#  '                            wichita falls, TX <small>(wtf)</small>\n'
#  '                        </label>\n'
#  '                        </li>\n'
#  '\n'
#  '                        <li>\n'
#  '                        <span class="nextNearbyZone linklike" '
#  'data-zone="1">\n'
#  '                            + show <span id="nearbyNumber">26</span> '
#  'more...\n'
#  '                        </span>\n'
#  '                        </li>\n'
#  '                </ul>\n'
#  '        </div>\n'
#  '\n'
#  '            <div class="searchgroup">\n'
#  '                <span class="searchfieldlabel">miles from zip</span>\n'
#  '                <input size="5" maxlength="5" inputmode="numeric"\n'
#  '                    class="flatinput searchInput search_distance" '
#  'placeholder="miles"\n'
#  '                    name="search_distance"\n'
#  '                    value=""\n'
#  '                />\n'
#  '                <input type="text" class="flatinput searchInput postal" '
#  'placeholder="from zip"\n'
#  '                    size="7" name="postal" value="">\n'
#  '                <span class="icon icon-locate"></span>\n'
#  '            </div>\n'
#  '\n'
#  '\n'
#  '    <div class="searchgroup minmax price">\n'
#  '<span class="searchfieldlabel">price</span>\n'
#  '    <input type="tel" name="min_price" class="flatinput min" '
#  'placeholder="min" title="whole number, no letters or symbols" value="">\n'
#  '    <input type="tel" name="max_price" class="flatinput max" '
#  'placeholder="max" title="whole number, no letters or symbols" value="">\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '        <div class="searchgroup"><span class="searchfieldlabel">make and '
#  'model</span>\n'
#  '    <input\n'
#  '        type="text"\n'
#  '        class="flatinput auto_make_model"\n'
#  '        placeholder="make / model"\n'
#  '        name="auto_make_model"\n'
#  '        value=""\n'
#  '        data-autocomplete="makemodel" />\n'
#  '</div><div class="searchgroup">    <div class="minmax '
#  'engine_displacement_cc">\n'
#  '<span class="searchfieldlabel">engine displacement (CC)</span>\n'
#  '    <input type="tel" name="min_engine_displacement_cc" class="flatinput '
#  'min" placeholder="min" title="whole number, no letters or symbols" '
#  'value="">\n'
#  '    <input type="tel" name="max_engine_displacement_cc" class="flatinput '
#  'max" placeholder="max" title="whole number, no letters or symbols" '
#  'value="">\n'
#  '</div>\n'
#  '    <div class="minmax auto_year">\n'
#  '<span class="searchfieldlabel">model year</span>\n'
#  '    <input type="tel" name="min_auto_year" class="flatinput min" '
#  'placeholder="min" title="whole number, no letters or symbols" value="">\n'
#  '    <input type="tel" name="max_auto_year" class="flatinput max" '
#  'placeholder="max" title="whole number, no letters or symbols" value="">\n'
#  '</div>\n'
#  '    <div class="minmax auto_miles">\n'
#  '<span class="searchfieldlabel">odometer</span>\n'
#  '    <input type="tel" name="min_auto_miles" class="flatinput min" '
#  'placeholder="min" title="whole number, no letters or symbols" value="">\n'
#  '    <input type="tel" name="max_auto_miles" class="flatinput max" '
#  'placeholder="max" title="whole number, no letters or symbols" value="">\n'
#  '</div>\n'
#  '</div><div class="searchgroup"><label class="motorcycle_street_legal">\n'
#  '        <input type="checkbox" name="motorcycle_street_legal" value="1" '
#  'class="autosubmit" />\n'
#  '    street legal\n'
#  '</label><br>\n'
#  '<label class="crypto_currency_ok">\n'
#  '        <input type="checkbox" name="crypto_currency_ok" value="1" '
#  'class="autosubmit" />\n'
#  '    cryptocurrency ok\n'
#  '</label><br>\n'
#  '<label class="delivery_available">\n'
#  '        <input type="checkbox" name="delivery_available" value="1" '
#  'class="autosubmit" />\n'
#  '    delivery available\n'
#  '</label><br>\n'
#  '</div><div class="searchgroup"><div class="search-attribute hide-list" '
#  'data-attr="language">\n'
#  '    <div class="title linklike ">\n'
#  '        <span class="plus">&#9656;</span><span class="minus">&#9662;</span> '
#  'language of posting\n'
#  '    </div>\n'
#  '\n'
#  '        <ul class="list">\n'
#  '\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_1" name="language" '
#  'class="multi_checkbox" value="1" type="checkbox"\n'
#  '                     />\n'
#  '                    af\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_2" name="language" '
#  'class="multi_checkbox" value="2" type="checkbox"\n'
#  '                     />\n'
#  '                    ca\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_3" name="language" '
#  'class="multi_checkbox" value="3" type="checkbox"\n'
#  '                     />\n'
#  '                    da\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_4" name="language" '
#  'class="multi_checkbox" value="4" type="checkbox"\n'
#  '                     />\n'
#  '                    de\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_5" name="language" '
#  'class="multi_checkbox" value="5" type="checkbox"\n'
#  '                     />\n'
#  '                    en\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_6" name="language" '
#  'class="multi_checkbox" value="6" type="checkbox"\n'
#  '                     />\n'
#  '                    es\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_7" name="language" '
#  'class="multi_checkbox" value="7" type="checkbox"\n'
#  '                     />\n'
#  '                    fi\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_8" name="language" '
#  'class="multi_checkbox" value="8" type="checkbox"\n'
#  '                     />\n'
#  '                    fr\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_9" name="language" '
#  'class="multi_checkbox" value="9" type="checkbox"\n'
#  '                     />\n'
#  '                    it\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_10" name="language" '
#  'class="multi_checkbox" value="10" type="checkbox"\n'
#  '                     />\n'
#  '                    nl\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_11" name="language" '
#  'class="multi_checkbox" value="11" type="checkbox"\n'
#  '                     />\n'
#  '                    no\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_12" name="language" '
#  'class="multi_checkbox" value="12" type="checkbox"\n'
#  '                     />\n'
#  '                    pt\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_13" name="language" '
#  'class="multi_checkbox" value="13" type="checkbox"\n'
#  '                     />\n'
#  '                    sv\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_14" name="language" '
#  'class="multi_checkbox" value="14" type="checkbox"\n'
#  '                     />\n'
#  '                    tl\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_15" name="language" '
#  'class="multi_checkbox" value="15" type="checkbox"\n'
#  '                     />\n'
#  '                    tr\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_16" name="language" '
#  'class="multi_checkbox" value="16" type="checkbox"\n'
#  '                     />\n'
#  '                    zh\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_17" name="language" '
#  'class="multi_checkbox" value="17" type="checkbox"\n'
#  '                     />\n'
#  '                    ar\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_18" name="language" '
#  'class="multi_checkbox" value="18" type="checkbox"\n'
#  '                     />\n'
#  '                    ja\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_19" name="language" '
#  'class="multi_checkbox" value="19" type="checkbox"\n'
#  '                     />\n'
#  '                    ko\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_20" name="language" '
#  'class="multi_checkbox" value="20" type="checkbox"\n'
#  '                     />\n'
#  '                    ru\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="language_21" name="language" '
#  'class="multi_checkbox" value="21" type="checkbox"\n'
#  '                     />\n'
#  '                    vi\n'
#  '                </label>\n'
#  '            </li>\n'
#  '\n'
#  '            <li class="selectall js-only ">\n'
#  '                <span class="all">select all</span>\n'
#  '                <span class="none">deselect all</span>\n'
#  '            </li>\n'
#  '\n'
#  '\n'
#  '    </ul>\n'
#  '</div>\n'
#  '<div class="search-attribute hide-list" data-attr="motorcycle_type">\n'
#  '    <div class="title linklike ">\n'
#  '        <span class="plus">&#9656;</span><span class="minus">&#9662;</span> '
#  'type\n'
#  '    </div>\n'
#  '\n'
#  '        <ul class="list">\n'
#  '\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_1" name="motorcycle_type" '
#  'class="multi_checkbox" value="1" type="checkbox"\n'
#  '                     />\n'
#  '                    bobber\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_2" name="motorcycle_type" '
#  'class="multi_checkbox" value="2" type="checkbox"\n'
#  '                     />\n'
#  '                    cafe racer\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_3" name="motorcycle_type" '
#  'class="multi_checkbox" value="3" type="checkbox"\n'
#  '                     />\n'
#  '                    chopper\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_4" name="motorcycle_type" '
#  'class="multi_checkbox" value="4" type="checkbox"\n'
#  '                     />\n'
#  '                    cruiser\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_5" name="motorcycle_type" '
#  'class="multi_checkbox" value="5" type="checkbox"\n'
#  '                     />\n'
#  '                    dirtbike\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_6" name="motorcycle_type" '
#  'class="multi_checkbox" value="6" type="checkbox"\n'
#  '                     />\n'
#  '                    dual-sport\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_7" name="motorcycle_type" '
#  'class="multi_checkbox" value="7" type="checkbox"\n'
#  '                     />\n'
#  '                    moped\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_8" name="motorcycle_type" '
#  'class="multi_checkbox" value="8" type="checkbox"\n'
#  '                     />\n'
#  '                    scooter\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_9" name="motorcycle_type" '
#  'class="multi_checkbox" value="9" type="checkbox"\n'
#  '                     />\n'
#  '                    sport bike\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_10" name="motorcycle_type" '
#  'class="multi_checkbox" value="10" type="checkbox"\n'
#  '                     />\n'
#  '                    sport touring\n'
#  '                </label>\n'
#  '            </li>\n'
#  '            <li class="checkbox ">\n'
#  '                <label>\n'
#  '                    <input id="motorcycle_type_11" name="motorcycle_type" '
#  'class="multi_checkbox" value="11" type="checkbox"\n'
#  '                     />\n'
# ...
#  '                <span class="result-price">$4600</span>\n'
#  '        </a>\n'
#  '\n'
#  '    <p class="result-info">\n'
#  '        <span class="icon icon-star" role="button">\n'
#  '            <span class="screen-reader-text">favorite this post</span>\n'
#  '        </span>\n'
#  '\n'
#  '            <time class="result-date" datetime="2020-04-28 13:20" title="Tue '
#  '28 Apr 01:20:28 PM">Apr 28</time>\n'
#  '\n'
#  '\n'
#  '        <a '
#  'href="https://austin.craigslist.org/mcy/d/austin-2006-sportster-1200-roadster/7115381323.html" '
#  'data-id="7115381323" class="result-title hdrlnk">2006 sportster 1200 '
#  'roadster</a>\n'
#  '\n'
#  '\n'
#  '        <span class="result-meta">\n'
#  '                <span class="result-price">$4600</span>\n'
#  '\n'
#  '\n'
#  '\n'
#  '                <span class="result-tags">\n'
#  '                    <span class="pictag">pic</span>\n'
#  '                </span>\n'
#  '\n'
#  '                <span class="banish icon icon-trash collapsed-trash" '
#  'role="button">\n'
#  '                    <span class="screen-reader-text">hide this '
#  'posting</span>\n'
#  '                </span>\n'
#  '\n'
#  '            <span class="unbanish icon icon-trash red" role="button" '
#  'aria-hidden="true"></span>\n'
#  '            <a href="#" class="restore-link">\n'
#  '                <span class="restore-narrow-text">restore</span>\n'
#  '                <span class="restore-wide-text">restore this posting</span>\n'
#  '            </a>\n'
#  '\n'
#  '        </span>\n'
#  '    </p>\n'
#  '</li>\n'
#  '         <li class="result-row" data-pid="7115359816">\n'
#  '\n'
#  '        <a '
#  'href="https://austin.craigslist.org/mcy/d/bastrop-2003-harley-fxstd-anniversary/7115359816.html" '
#  'class="result-image gallery" data-ids="1:00Z0Z_5k5XDMIBiye">\n'
#  '                <span class="result-price">$7500</span>\n'
#  '        </a>\n'
#  '\n'
#  '    <p class="result-info">\n'
#  '        <span class="icon icon-star" role="button">\n'
#  '            <span class="screen-reader-text">favorite this post</span>\n'
#  '        </span>\n'
#  '\n'
#  '            <time class="result-date" datetime="2020-04-28 12:48" title="Tue '
#  '28 Apr 12:48:48 PM">Apr 28</time>\n'
#  '\n'
#  '\n'
#  '        <a '
#  'href="https://austin.craigslist.org/mcy/d/bastrop-2003-harley-fxstd-anniversary/7115359816.html" '
#  'data-id="7115359816" class="result-title hdrlnk">2003 Harley FXSTD '
#  'anniversary Edition</a>\n'
#  '\n'
#  '\n'
#  '        <span class="result-meta">\n'
#  '                <span class="result-price">$7500</span>\n'
#  '\n'
#  '\n'
#  '\n'
#  '                <span class="result-tags">\n'
#  '                    <span class="pictag">pic</span>\n'
#  '                </span>\n'
#  '\n'
#  '                <span class="banish icon icon-trash collapsed-trash" '
#  'role="button">\n'
#  '                    <span class="screen-reader-text">hide this '
#  'posting</span>\n'
#  '                </span>\n'
#  '\n'
#  '            <span class="unbanish icon icon-trash red" role="button" '
#  'aria-hidden="true"></span>\n'
#  '            <a href="#" class="restore-link">\n'
#  '                <span class="restore-narrow-text">restore</span>\n'
#  '                <span class="restore-wide-text">restore this posting</span>\n'
#  '            </a>\n'
#  '\n'
#  '        </span>\n'
#  '    </p>\n'
#  '</li>\n'
#  '         <li class="result-row" data-pid="7115355999">\n'
#  '\n'
#  '        <a '
#  'href="https://austin.craigslist.org/mcd/d/boerne-2020-indian-roadmaster-elite/7115355999.html" '
#  'class="result-image gallery" '
#  'data-ids="1:00Z0Z_84vkc0V72JB,1:00h0h_eSbzDHURQvw,1:00K0K_dsMRnuRBAdV,1:00909_SnAGqz1cLN,1:00C0C_5AGRywsYK1C,1:00a0a_jDfArNgupy9,1:00m0m_fVOSqSaNUb7,1:00r0r_6HD228Tqmil,1:00Z0Z_fGEBqw8QWaq,1:00E0E_d4qbdrauFEB,1:00C0C_aGEHIwMQ7Lw,1:00l0l_50lUpmoEWDD,1:00p0p_9SGfyynK0Jc,1:00d0d_1p5Pj3OG4V3,1:00F0F_imygX6KjAPT,1:00Z0Z_gmffsXfrf3o,1:00o0o_jtVT9x8yqCm,1:00909_5sl5uMkfz1,1:00606_dqpkwKjrlj3,1:00C0C_cJ68ZCXqEv3,1:00b0b_jNCsqCg7Vmq,1:00k0k_csi4NBnI3Sz,1:01616_9vPjWAkEbhA,1:00P0P_ibdBZgjfXDz">\n'
#  '                <span class="result-price">$38999</span>\n'
#  '        </a>\n'
#  '\n'
#  '    <p class="result-info">\n'
#  '        <span class="icon icon-star" role="button">\n'
#  '            <span class="screen-reader-text">favorite this post</span>\n'
#  '        </span>\n'
#  '\n'
#  '            <time class="result-date" datetime="2020-04-28 12:43" title="Tue '
#  '28 Apr 12:43:13 PM">Apr 28</time>\n'
#  '\n'
#  '\n'
#  '        <a '
#  'href="https://austin.craigslist.org/mcd/d/boerne-2020-indian-roadmaster-elite/7115355999.html" '
#  'data-id="7115355999" class="result-title hdrlnk">2020 Indian Roadmaster '
#  'Elite Thunder Black Vivid Crystal Over V Twin</a>\n'
#  '\n'
#  '\n'
#  '        <span class="result-meta">\n'
#  '                <span class="result-price">$38999</span>\n'
#  '\n'
#  '\n'
#  '\n'
#  '                <span class="result-tags">\n'
#  '                    <span class="pictag">pic</span>\n'
#  '                </span>\n'
#  '\n'
#  '                <span class="banish icon icon-trash collapsed-trash" '
#  'role="button">\n'
#  '                    <span class="screen-reader-text">hide this '
#  'posting</span>\n'
#  '                </span>\n'
#  '\n'
#  '            <span class="unbanish icon icon-trash red" role="button" '
#  'aria-hidden="true"></span>\n'
#  '            <a href="#" class="restore-link">\n'
#  '                <span class="restore-narrow-text">restore</span>\n'
#  '                <span class="restore-wide-text">restore this posting</span>\n'
#  '            </a>\n'
#  '\n'
#  '        </span>\n'
#  '    </p>\n'
#  '</li>\n'
#  '\n'
#  '                    \n'
#  '                    \n'
#  '                </ul>\n'
#  '            </div>\n'
#  '\n'
#  '            <div class="search-legend bottom">\n'
#  '                <div class="search-view">\n'
#  '                    <span class="buttongroup"><a class="backtotop button" '
#  'href="#page-top">^ back to top</a></span>\n'
#  '                </div>\n'
#  '                <div class="search-sort">\n'
#  '                    <span class="buttongroup"><a class="backtotop button" '
#  'href="#page-top">^ back to top</a></span>\n'
#  '                </div>\n'
#  '                <div class="paginator buttongroup firstpage">\n'
#  '    <span class="resulttotal">\n'
#  '        <span class="for-map">\n'
#  '        displaying <span class="displaycountShow">...</span> postings\n'
#  '        </span>\n'
#  '    </span>\n'
#  '    <span class="buttons">\n'
#  '        <a href="/search/mca?bundleDuplicates=1" class="button first" '
#  'title="first page">&lt;&lt;</a>\n'
#  '        <span class="button first" title="first page">&lt;&lt;</span>\n'
#  '        <a href="/search/mca?bundleDuplicates=1" class="button prev" '
#  'title="previous page">&lt; prev</a>\n'
#  '        <span class="button prev" title="previous page">&lt; prev</span>\n'
#  '\n'
#  '        <span class="button pagenum">\n'
#  '            <span class="range">\n'
#  '                <span class="rangeFrom">1</span>\n'
#  '                -\n'
#  '                <span class="rangeTo">120</span>\n'
#  '            </span>\n'
#  '            /\n'
#  '            <span class="totalcount">560</span>\n'
#  '        </span>\n'
#  '\n'
#  '        <a href="/search/mca?s=120&amp;bundleDuplicates=1" class="button '
#  'next" title="next page">next &gt; </a>\n'
#  '        <span class="button next" title="next page"> next &gt; </span>\n'
#  '    </span>\n'
#  '</div>\n'
#  '\n'
#  '            </div>\n'
#  '\n'
#  '            <section class="blurbs">\n'
#  '                \n'
#  '            </section>\n'
#  '\n'
#  '            <div id="floater">\n'
#  '                <img class="loading" '
#  'src="//www.craigslist.org/images/animated-spinny.gif" alt="">\n'
#  '                <img class="payload" '
#  'src="//www.craigslist.org/images/animated-spinny.gif" alt="">\n'
#  '            </div>\n'
#  '        </form>\n'
#  '\n'
#  '<aside class="tsb">\n'
#  '    <ul>\n'
#  '        <li><a href="https://www.craigslist.org/about/safety">safety '
#  'tips</a>\n'
#  '        <li><a href="https://www.craigslist.org/about/prohibited">prohibited '
#  'items</a>\n'
#  '        <li><a '
#  'href="https://www.craigslist.org/about/recalled_items">product recalls</a>\n'
#  '        <li><a href="https://www.craigslist.org/about/scams">avoiding '
#  'scams</a>\n'
#  '    </ul>\n'
#  '</aside>\n'
#  '\n'
#  '<div class="slidemessage">\n'
#  '    <span class="fave">\n'
#  '        <span class="star"></span>\n'
#  '        favorited\n'
#  '    </span>\n'
#  '    <span class="unfave">\n'
#  '        <span class="star"></span>\n'
#  '        no longer favorited\n'
#  '    </span>\n'
#  '    <span class="hide">\n'
#  '        <span class="trash"></span>\n'
#  '        hidden\n'
#  '    </span>\n'
#  '    <span class="unhide">\n'
#  '        <span class="trash"></span>\n'
#  '        no longer hidden\n'
#  '    </span>\n'
#  '</div>\n'
#  '\n'
#  '<footer>\n'
#  '        <span class="rss">\n'
#  '            <a class="l" '
#  'href="https://austin.craigslist.org/search/mca?bundleDuplicates=1&amp;format=rss">RSS</a>\n'
#  '            <a href="https://www.craigslist.org/about/rss">(?)</a><br>\n'
#  '        </span>\n'
#  '    <ul class="clfooter">\n'
#  '        <li>&copy;  <span class="desktop">craigslist</span><span '
#  'class="mobile">CL</span></li>\n'
#  '        <li><a href="https://www.craigslist.org/about/help/">help</a></li>\n'
#  '        <li><a '
#  'href="https://www.craigslist.org/about/scams">safety</a></li>\n'
#  '        <li class="desktop"><a '
#  'href="https://www.craigslist.org/about/privacy.policy">privacy</a></li>\n'
#  '        <li class="desktop"><a '
#  'href="https://forums.craigslist.org/?forumID=8">feedback</a></li>\n'
#  '        <li class="desktop"><a '
#  'href="https://www.craigslist.org/about/craigslist_is_hiring">cl '
#  'jobs</a></li>\n'
#  '        <li><a '
#  'href="//www.craigslist.org/about/terms.of.use.en-us">terms</a><sup '
#  'class="neu">new</sup></li>\n'
#  '        <li><a href="https://www.craigslist.org/about/">about</a></li>\n'
#  '        <li class="fsel desktop linklike" data-mode="mobile">mobile</li>\n'
#  '        <li class="fsel mobile linklike" data-mode="regular">desktop</li>\n'
#  '    </ul>\n'
#  '</footer>\n'
#  '    </section>\n'
#  '\n'
#  '    <template id="gallerycarousel">\n'
#  '        <div class="slider-info"></div><div class="slider-back '
#  'arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>\n'
#  '    </template>\n'
#  '\n'
#  '    \n'
#  '                <script>\n'
#  '                try {\n'
#  '                    if (\n'
#  '                        '
#  '!/\\/\\/.+\\.craigslist\\.org\\/about\\//.test(window.location.href)\n'
#  '                        &&\n'
#  '                        (!window.addEventListener || '
#  "JSON.parse(JSON.stringify('x')) !== 'x')\n"
#  '                    ) {\n'
#  '                        throw "unsupported browser";\n'
#  '                    }\n'
#  '                } catch (e) {\n'
#  '                    function cleanup() {\n'
#  "                        document.body.innerHTML = '<div "
#  'id="cl-unsupported-browser" '
#  'style="margin:1em;font-size:150%;text-align:center;">We have detected you '
#  'are using a browser that is missing critical features.<br><br>Please visit '
#  "craigslist from a modern browser.</div>';\n"
#  '                        document.body.style = "display:block";\n'
#  '                    }\n'
#  '\n'
#  '                    try {\n'
#  '                        document.body.style = "display:none";\n'
#  '                    } catch (e) {\n'
#  '                    }\n'
#  '                    window.onload = cleanup;\n'
#  '                    window.clUnsupportedBrowser = true;\n'
#  '                }\n'
#  '                </script>\n'
#  '            <script '
#  'src="//www.craigslist.org/js/general-concat.min.js?v=8ee49526dc97855394156aa727f29a35" '
#  'type="text/javascript" ></script>\n'
#  '\n'
#  '<script type="text/template" id="clustertemplate">\n'
#  '    <li class="posting {visited}" data-pid="{PostingID}">\n'
#  '        <img src="{ImageThumb}">\n'
#  '        <div class="housing_bubble_banner">\n'
#  '            <span class="{hasPrice}price">{currencySymbol}{Ask}</span>\n'
#  '            <span class="bedrooms">{BedroomsContent}</span>\n'
#  '            <span class="postingtitle"><a>{PostingTitle}</a></span>\n'
#  '            <span class="js-only map-banish-unbanish" '
#  'data-pid="{PostingID}">\n'
#  '                <span class="banish">\n'
#  '                    <span class="icon icon-trash" role="button"></span>\n'
#  '                    <span class="screen-reader-text">hide this '
#  'posting</span>\n'
#  '                </span>\n'
#  '                <span class="unbanish">\n'
#  '                    <span class="icon icon-trash red" role="button"></span>\n'
#  '                    unhide\n'
#  '                </span>\n'
#  '            </span>\n'
#  '        </div>\n'
#  '    </li>\n'
#  '</script>\n'
#  '<script type="text/template" id="postingtemplate">\n'
#  '    <div class="viewcontainer pics loading">\n'
#  '        <div class="backtolist">\n'
#  '            &laquo; back to posting list\n'
#  '        </div>\n'
#  '        <div class="title">\n'
#  '            <span class="icon icon-star" data-pid="{PostingID}" '
#  'role="button">\n'
#  '                <span class="screen-reader-text">favorite this post</span>\n'
#  '            </span>\n'
#  '            <span class="postingtitle">\n'
#  '                <a href="{PostingURL}" target="_blank">{PostingTitle}</a>\n'
#  '            </span>\n'
#  '            <div>\n'
#  '                <span class="{hasPrice}price">{currencySymbol}{Ask}</span>\n'
#  '                <span class="bedrooms">{BedroomsContent}</span>\n'
#  '                <span class="js-only map-banish-unbanish" '
#  'data-pid="{PostingID}">\n'
#  '                    <span class="banish">\n'
#  '                        <span class="icon icon-trash" role="button"></span>\n'
#  '                        <span class="screen-reader-text">hide this '
#  'posting</span>\n'
#  '                    </span>\n'
#  '                    <span class="unbanish">\n'
#  '                        <span class="icon icon-trash red" '
#  'role="button"></span>\n'
#  '                        <span class="screen-reader-text">unhide</span>\n'
#  '                        unhide\n'
#  '                    </span>\n'
#  '                </span>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '        <hr style="clear:both">\n'
#  '        <div class="picscontainer gallery">\n'
#  '            <span class="slider-back arrow">&lt;</span><span '
#  'class="slider-info"></span><span class="slider-forward arrow">&gt;</span>\n'
#  '            <div class="swipe">\n'
#  '                <div class="swipe-wrap">\n'
#  '                    <img class="loading" '
#  'src="//www.craigslist.org/images/animated-spinny.gif" alt="">\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '        <div class="infocontainer"></div>\n'
#  '        <hr style="clear:both">\n'
#  '        <div class="timecontainer"></div>\n'
#  '        <a class="viewpostinglink" href="{PostingURL}" target="_blank">view '
#  'posting</a>\n'
#  '        <div class="contenttoggle">\n'
#  '            <a class="moreinfo">more info</a>\n'
#  '            <a class="showpics">show images</a>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</script>\n'
#  '<script type="text/template" id="popuptemplate">\n'
#  '    <div id="mapbubble" class="posting">\n'
#  '        <ul id="clusterbubble"></ul>\n'
#  '        <div id="postbubble"></div>\n'
#  '    </div>\n'
#  '</script>\n'
#  '    <script '
#  'src="//www.craigslist.org/js/leaflet-concat.min.js?v=4ff49d1f1bfa74f1aa8a9515db6c11f0" '
#  'type="text/javascript" ></script>\n'
#  '\n'
#  '    <script '
#  'src="//www.craigslist.org/js/search-concat.min.js?v=f46a6adc3b0884e335cb303d3a0ccfe9" '
#  'type="text/javascript" ></script>\n'
#  '\n'
#  '    <script '
#  'src="//www.craigslist.org/js/postings-concat.min.js?v=6f74ffb0d6d8ba86b4d726230053a3f9" '
#  'type="text/javascript" ></script>\n'
#  '\n'
#  '</body>\n'
#  '</html>\n')

# %%
post_one = posts[0]
post_one
# Out:
# <li class="result-row" data-pid="7118000776">
# <a class="result-image gallery" data-ids="1:00y0y_1MZQ18UBUzT,1:00u0u_2inT4jmdglk,1:00D0D_9luoldEP9z5,1:00e0e_6FcoGmtz9K5" href="https://austin.craigslist.org/mcy/d/cedar-park-superb-hd-dyna-superglide/7118000776.html">
# <span class="result-price">$6250</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2020-05-03 12:40" title="Sun 03 May 12:40:22 PM">May  3</time>
# <a class="result-title hdrlnk" data-id="7118000776" href="https://austin.craigslist.org/mcy/d/cedar-park-superb-hd-dyna-superglide/7118000776.html">Superb HD Dyna Superglide</a>
# <span class="result-meta">
# <span class="result-price">$6250</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash collapsed-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>

# %%
post_one_title = post_one.find_all('a', class_='result-title hdrlnk')
post_one_title
# Out:
# [<a class="result-title hdrlnk" data-id="7118000776" href="https://austin.craigslist.org/mcy/d/cedar-park-superb-hd-dyna-superglide/7118000776.html">Superb HD Dyna Superglide</a>]

# %%
post_one_price = post_one.a.text
post_one_price.strip()
# Out:
# '$6250'

# %%
post_one_hood = post_one.find('span', class_= 'result-hood')
post_one_hood

# %%
post_one_time = post_one.find('time', class_= 'result-date')
post_one_datetime = post_one_time['datetime']
post_one_datetime
# Out:
# '2020-05-03 12:40'

# %%
'''This bit of code is in the process of being built. It will scrape a page on 
craigslist for all features and text for a motorcycle posting.'''

page_motor = requests.get('https://bham.craigslist.org/mcy/d/lynnville-harley-davidson-street-glide/7120104629.html')
    
soup_motor = BeautifulSoup(page_motor.text, 'html.parser')

title = soup_motor.find('span', id = 'titletextonly').text
price = soup_motor.find('span', class_ = 'price').text
neighborhood = soup_motor.find('small').text
attributes = soup_motor.find_all('p', attrs = {'class': 'attrgroup'})
description = soup_motor.find('section', id = 'postingbody').text

# header=soup_motor.find_all("span",attrs={"id":"titletextonly"})
# condition = soup_motor.find('p', attrs ={'class': 'attrgroup'})
# description = soup_motor.find('section', id_='postingbody')
title, price, neighborhood, attributes, description
# Out:
# ('Harley-Davidson Street Glide Electra Glide-Low miles!',
#  '$7500',
#  ' (Lynnville tn)',
#  [<p class="attrgroup">
#   <span><b>2008 harley davidson</b></span>
#   <br/>
#   </p>,
#   <p class="attrgroup">
#   <span>condition: <b>excellent</b></span>
#   <br/>
#   <span>fuel: <b>gas</b></span>
#   <br/>
#   <span>paint color: <b>black</b></span>
#   <br/>
#   <span>title status: <b>clean</b></span>
#   <br/>
#   <span>transmission: <b>manual</b></span>
#   <br/>
#   <span>type: <b>touring</b></span>
#   <br/>
#   </p>],
#  '\n\nQR Code Link to This Post\n\n\nThis is a very nice 2008 Harley-Davidson Electra Glide set up like a Street Glide with only 40k miles. 96 cu in motor. 6 speed. 2010 Street Glide exhaust. Has all Street Glide options and more including: Cruise control, Pioneer stereo, lowering kit, HD low profile seat, oil pressure gauge, 12" mini apes with braided lines, chrome(switch buttons, console, dash cover, light bezels, horn cover, voltage reg cover, point cover) and more. $7500. Clear title in hand. NO TRADES!! 931-619-9300    ')

# %%
price
# Out:
# []

# %%
# This will collect the links for all cities on craigslist. We will have to sparse through
# these and cut out the non-US cities.
def city_link_collector():
    # this is the craigslist page with every city
    main_page = requests.get('https://www.craigslist.org/about/sites')
    soup = BeautifulSoup(main_page.text, 'html.parser')
    
    all_list = []
    uscity_list = []
    city_list = []
    
    for i in range(4):
        for box in soup.find_all('div', class_='box box_{}'.format(i+1)):
            all_list.append(box.find_all('a'))
    for _ in all_list[:20:7]:
        for __ in _:
            uscity_list.append(__)
    for ___ in all_list[20][0:94]:
        uscity_list.append(___)
    
    for idx, city in enumerate(uscity_list):
        city_list.append(str(uscity_list[idx]).split('''"''')[1])
    
    return city_list
    #                     #posting date
    #                     #grab the datetime element 0 for date and 1 for time
    #                     post_datetime = box.find('time', class_= 'result-date')['datetime']
    #                     post_timing.append(post_datetime)

# %%
city_list = city_link_collector()
city_list
# Out:
# ['https://auburn.craigslist.org/',
#  'https://bham.craigslist.org/',
#  'https://dothan.craigslist.org/',
#  'https://shoals.craigslist.org/',
#  'https://gadsden.craigslist.org/',
#  'https://huntsville.craigslist.org/',
#  'https://mobile.craigslist.org/',
#  'https://northernwi.craigslist.org/',
#  'https://sheboygan.craigslist.org/',
#  'https://wausau.craigslist.org/',
#  'https://wyoming.craigslist.org/']

# %%
post_timing = []
post_hoods = []
post_title_texts = []
post_links = []
post_prices = []
city_names = []
city_names = []

for city in city_list[0:3]: 
    
    #get the first page of the Austin motorcycle prices
    response = requests.get('{}search/mca?s=0&bundleDuplicates=1'.format(city))
    #parse through it and make it readable
    html_soup = BeautifulSoup(response.text, 'html.parser')
    #find the total number of posts to find the limit for each page
    results_num = html_soup.find('div', class_= 'search-legend')
    #pulled the total count of posts as the upper bound of the pages array
    results_total = int(results_num.find('span', class_='totalcount').text) 
    #each page has 119 posts so each new page is defined as follows: s=120, s=240, s=360, and so on. So we need to step in size 120 in the np.arange function
    pages = np.arange(0, results_total+1, 120)
    print("{} Pages = {}".format(city.title(), len(pages)))

    iterations = 0

    for page in pages:         
        #get request
        post_timing_ = []
        post_hoods_ = []
        post_title_texts_ = []
        post_links_ = []
        post_prices_ = []
        city_names_ = []
        
        response = requests.get("{}search/mca?".format(city) 
                       + "s=" #the parameter for defining the page number 
                       + str(page) #the page number in the pages array from earlier
                       + "&bundleDuplicates=1")

        time.sleep(random.randint(5,10))

        #throw warning for status codes that are not 200
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requests, response.status_code))

        #define the html text
        page_html = BeautifulSoup(response.text, 'html.parser')

        #define the posts
        posts = page_html.find_all('li', class_= 'result-row')

        #extract data by item
        for post in posts:
                                   
            if post.find('span', class_ = 'result-hood') is not None:

                #posting date
                #grab the datetime element 0 for date and 1 for time
                post_datetime = post.find('time', class_= 'result-date')['datetime']
                post_timing_.append(post_datetime)

                #neighborhoods
                post_hood = post.find('span', class_= 'result-hood').text
                post_hoods_.append(post_hood)

                #title text
                post_title = post.find('a', class_='result-title hdrlnk')
                post_title_text = post_title.text
                post_title_texts_.append(post_title_text)

                #post link
                post_link = post_title['href']
                post_links_.append(post_link)

                #removes the \n whitespace from each side, removes the currency symbol, and turns it into an int
                post_price = (post.a.text.strip().replace("$", "")) 
                post_prices_.append(post_price)

                #add the city's name to the row
                city_names_.append(city)
        iterations += 1
        print("{} Page ".format(city.title()) + str(iterations) + " of {} pages".format(len(pages)) + " scraped successfully!")
        print(len(post_links_))
    post_timing.append(post_timing_)
    post_hoods.append(post_hoods_)
    post_title_texts.append(post_title_texts_)
    post_links.append(post_links_)
    post_prices.append(post_prices_)
    city_names.append(city_names_)
    
        
    print("\n")

    print("{} complete!".format(city.title()))
    print(str(len(post_links_)) + " rows collected.")
len(post_timing), len(post_hoods), len(post_title_texts), len(post_links), len(post_prices), len(city_names)
# Out:
# Https://Auburn.Craigslist.Org/ Pages = 1
# Https://Auburn.Craigslist.Org/ Page 1 of 1 pages scraped successfully!
# 6
#
#
# Https://Auburn.Craigslist.Org/ complete!
# 6 rows collected.
# Https://Bham.Craigslist.Org/ Pages = 1
# Https://Bham.Craigslist.Org/ Page 1 of 1 pages scraped successfully!
# 100
#
#
# Https://Bham.Craigslist.Org/ complete!
# 100 rows collected.
# Https://Dothan.Craigslist.Org/ Pages = 1
# Https://Dothan.Craigslist.Org/ Page 1 of 1 pages scraped successfully!
# 20
#
#
# Https://Dothan.Craigslist.Org/ complete!
# 20 rows collected.
# (3, 3, 3, 3, 3, 3)

# %%
len(post_timing), post_timing
# Out:
# (3,
#  [['2020-05-07 18:10',
#    '2020-05-06 15:26',
#    '2020-05-04 23:00',
#    '2020-04-26 13:49',
#    '2020-04-26 13:13',
#    '2020-04-20 13:18'],
#   ['2020-05-09 21:42',
#    '2020-05-09 15:08',
#    '2020-05-09 13:53',
#    '2020-05-09 13:10',
#    '2020-05-09 10:10',
#    '2020-05-09 00:24',
#    '2020-05-08 06:51',
#    '2020-04-16 04:26',
#    '2020-05-07 20:21',
#    '2020-05-07 19:01',
#    '2020-05-07 18:59',
#    '2020-05-07 17:36',
#    '2020-05-07 14:32',
#    '2020-05-07 09:40',
#    '2020-05-06 07:36',
#    '2020-05-05 17:31',
#    '2020-05-05 14:03',
#    '2020-05-05 08:56',
#    '2020-05-05 08:40',
#    '2020-05-04 17:08',
#    '2020-05-04 16:00',
#    '2020-05-04 14:50',
#    '2020-05-04 14:31',
#    '2020-05-04 13:51',
#    '2020-05-04 09:08',
#    '2020-05-03 19:15',
#    '2020-05-03 16:55',
#    '2020-05-03 14:30',
#    '2020-05-03 13:50',
#    '2020-05-03 11:14',
#    '2020-05-02 20:31',
#    '2020-05-02 19:24',
#    '2020-05-02 09:36',
#    '2020-05-02 08:41',
#    '2020-05-02 06:53',
#    '2020-05-01 11:18',
#    '2020-04-30 20:27',
#    '2020-04-30 10:36',
#    '2020-04-30 10:24',
#    '2020-04-30 09:50',
#    '2020-04-30 09:34',
#    '2020-04-30 09:26',
#    '2020-04-30 09:10',
#    '2020-04-29 19:49',
#    '2020-04-29 19:48',
#    '2020-04-29 18:09',
#    '2020-04-29 10:59',
#    '2020-04-29 08:56',
#    '2020-04-28 11:12',
#    '2020-04-27 15:51',
#    '2020-04-27 15:40',
#    '2020-04-27 13:52',
#    '2020-04-27 13:43',
#    '2020-04-27 13:28',
#    '2020-04-27 11:04',
#    '2020-04-26 13:59',
#    '2020-04-25 19:44',
#    '2020-04-25 07:21',
#    '2020-04-25 05:19',
#    '2020-04-24 19:34',
#    '2020-04-24 15:30',
#    '2020-04-24 15:30',
#    '2020-04-24 15:10',
#    '2020-04-24 11:42',
#    '2020-04-24 07:12',
#    '2020-04-24 03:23',
#    '2020-04-23 21:14',
#    '2020-04-23 20:52',
#    '2020-04-23 18:54',
#    '2020-04-23 08:11',
#    '2020-04-22 22:02',
#    '2020-04-22 21:21',
#    '2020-04-21 21:05',
#    '2020-04-21 13:59',
#    '2020-04-21 13:57',
#    '2020-04-19 18:42',
#    '2020-04-18 23:28',
#    '2020-04-18 17:28',
#    '2020-04-18 17:22',
#    '2020-04-17 15:54',
#    '2020-04-17 12:27',
#    '2020-04-17 12:26',
#    '2020-04-17 11:07',
#    '2020-04-17 09:44',
#    '2020-04-16 20:44',
#    '2020-04-16 18:16',
#    '2020-04-16 13:44',
#    '2020-04-16 12:28',
#    '2020-04-16 09:06',
#    '2020-04-15 11:19',
#    '2020-04-14 16:02',
#    '2020-04-13 18:54',
#    '2020-04-13 11:55',
#    '2020-04-13 08:34',
#    '2020-04-12 12:32',
#    '2020-04-11 14:04',
#    '2020-04-10 15:41',
#    '2020-04-10 12:52',
#    '2020-04-10 12:32',
#    '2020-04-10 12:15'],
#   ['2020-05-09 09:06',
#    '2020-05-06 18:32',
#    '2020-05-06 13:27',
#    '2020-05-04 19:47',
#    '2020-05-03 06:33',
#    '2020-05-02 08:59',
#    '2020-05-01 12:33',
#    '2020-05-01 12:26',
#    '2020-05-01 12:20',
#    '2020-05-01 10:50',
#    '2020-05-01 10:47',
#    '2020-04-30 15:15',
#    '2020-04-29 14:17',
#    '2020-04-26 18:56',
#    '2020-04-25 19:12',
#    '2020-04-22 10:57',
#    '2020-04-19 15:38',
#    '2020-04-17 19:17',
#    '2020-04-17 19:11',
#    '2020-04-11 18:31']])

# %%
# Out:
# 243

# %%
def craigslist_motorcycle_scraper(city_list):

    title = []
    price = []
    neighborhood = []
    attributes = []
    description = []
    city_names = []

    for city in city_list: 

        #get the first page of the Austin motorcycle prices
        response = requests.get('{}search/mca?s=0&bundleDuplicates=1'.format(city))
        #parse through it and make it readable
        html_soup = BeautifulSoup(response.text, 'html.parser')
        #find the total number of posts to find the limit for each page
        results_num = html_soup.find('div', class_= 'search-legend')
        #pulled the total count of posts as the upper bound of the pages array
        results_total = int(results_num.find('span', class_='totalcount').text) 
        #each page has 119 posts so each new page is defined as follows: s=120, s=240, s=360, and so on. So we need to step in size 120 in the np.arange function
        pages = np.arange(0, results_total+1, 120)
        print("{} Pages = {}".format(city.title(), len(pages)))

        iterations = 0



        for page in pages:         
            title_ = []
            price_ = []
            neighborhood_ = []
            attributes_ = []
            description_ = []
            city_names_ = []
            #get request      
            response = requests.get("{}search/mca?".format(city) 
                           + "s=" #the parameter for defining the page number 
                           + str(page) #the page number in the pages array from earlier
                           + "&bundleDuplicates=1")

            time.sleep(random.randint(5,10))

            #throw warning for status codes that are not 200
            if response.status_code != 200:
                warn('Request: {}; Status code: {}'.format(requests, response.status_code))

            #define the html text
            post_soup = BeautifulSoup(response.text, 'html.parser')

            #define the posts
    #         posts = page_html.find_all('li', class_= 'result-row')

            #extract data by item
    #         for post in posts:
            count = 0
            for post in post_soup.find_all('a', class_ = 'result-title hdrlnk'):
                link = post['href']
                sub_post = requests.get(link)
                sub_soup = BeautifulSoup(sub_post.text, 'html.parser')

    #             if tag.find('small') is not None:

                post_title = sub_soup.find('span', id = 'titletextonly')
                title_.append(post_title)

                post_price = sub_soup.find('span', class_ = 'price')
                price_.append(post_price)

                post_neighborhood = sub_soup.find('small')
                neighborhood_.append(post_neighborhood)

                post_attributes = sub_soup.find_all('p', attrs = {'class': 'attrgroup'})
                attributes_.append(post_attributes)

                post_description = sub_soup.find('section', id = 'postingbody')
                description_.append(post_description)

                city_names_.append(city)

                time.sleep(random.randint(2,3))
                count += 1
                print("{} of {} posts scraped".format(count, results_total))

                if count == results_total:
                    break

            iterations += 1
            print("{} Page ".format(city.title()) + str(iterations) + " of {} pages".format(len(pages)) + " scraped successfully!")

            title.append(title_)
            price.append(price_)
            neighborhood.append(neighborhood_)
            attributes.append(attributes_)
            description.append(description_)
            city_names.append(city_names_)


        print("\n")

        print("{} complete!".format(city.title()))
        print(str(len(title_)) + " rows collected.")
    return title, price, neighborhood, attributes, description, city_names

# %%
title, price, neighborhood, attributes, description, city = craigslist_motorcycle_scraper(city_list)
# Out:
# Https://Auburn.Craigslist.Org/ Pages = 1
# 1 of 7 posts scraped
# 2 of 7 posts scraped
# 3 of 7 posts scraped
# 4 of 7 posts scraped
# 5 of 7 posts scraped
# 6 of 7 posts scraped
# 7 of 7 posts scraped
# Https://Auburn.Craigslist.Org/ Page 1 of 1 pages scraped successfully!
#
#
# Https://Auburn.Craigslist.Org/ complete!
# 7 rows collected.
# Https://Bham.Craigslist.Org/ Pages = 1
# 1 of 106 posts scraped
# 2 of 106 posts scraped
# 3 of 106 posts scraped
# 4 of 106 posts scraped
# 5 of 106 posts scraped
# 6 of 106 posts scraped
# 7 of 106 posts scraped
# 8 of 106 posts scraped
# 9 of 106 posts scraped
# 10 of 106 posts scraped
# 11 of 106 posts scraped
# 12 of 106 posts scraped
# 13 of 106 posts scraped
# 14 of 106 posts scraped
# 15 of 106 posts scraped
# 16 of 106 posts scraped
# 17 of 106 posts scraped
# 18 of 106 posts scraped
# 19 of 106 posts scraped
# 20 of 106 posts scraped
# 21 of 106 posts scraped
# 22 of 106 posts scraped
# 23 of 106 posts scraped
# 24 of 106 posts scraped
# 25 of 106 posts scraped
# 26 of 106 posts scraped
# 27 of 106 posts scraped
# 28 of 106 posts scraped
# 29 of 106 posts scraped
# 30 of 106 posts scraped
# 31 of 106 posts scraped
# 32 of 106 posts scraped
# 33 of 106 posts scraped
# 34 of 106 posts scraped
# 35 of 106 posts scraped
# 36 of 106 posts scraped
# 37 of 106 posts scraped
# 38 of 106 posts scraped
# 39 of 106 posts scraped
# 40 of 106 posts scraped
# 41 of 106 posts scraped
# 42 of 106 posts scraped
# 43 of 106 posts scraped
# 44 of 106 posts scraped
# 45 of 106 posts scraped
# 46 of 106 posts scraped
# 47 of 106 posts scraped
# 48 of 106 posts scraped
# 49 of 106 posts scraped
# 50 of 106 posts scraped
# 51 of 106 posts scraped
# 52 of 106 posts scraped
# 53 of 106 posts scraped
# 54 of 106 posts scraped
# 55 of 106 posts scraped
# 56 of 106 posts scraped
# 57 of 106 posts scraped
# 58 of 106 posts scraped
# 59 of 106 posts scraped
# 60 of 106 posts scraped
# 61 of 106 posts scraped
# 62 of 106 posts scraped
# 63 of 106 posts scraped
# 64 of 106 posts scraped
# 65 of 106 posts scraped
# 66 of 106 posts scraped
# 67 of 106 posts scraped
# 68 of 106 posts scraped
# 69 of 106 posts scraped
# 70 of 106 posts scraped
# 71 of 106 posts scraped
# 72 of 106 posts scraped
# 73 of 106 posts scraped
# 74 of 106 posts scraped
# 75 of 106 posts scraped
# 76 of 106 posts scraped
# 77 of 106 posts scraped
# 78 of 106 posts scraped
# 79 of 106 posts scraped
# 80 of 106 posts scraped
# 81 of 106 posts scraped
# 82 of 106 posts scraped
# 83 of 106 posts scraped
# 84 of 106 posts scraped
# 85 of 106 posts scraped
# 86 of 106 posts scraped
# 87 of 106 posts scraped
# 88 of 106 posts scraped
# 89 of 106 posts scraped
# 90 of 106 posts scraped
# 91 of 106 posts scraped
# 92 of 106 posts scraped
# 93 of 106 posts scraped
# 94 of 106 posts scraped
# 95 of 106 posts scraped
# 96 of 106 posts scraped
# 97 of 106 posts scraped
# 98 of 106 posts scraped
# 99 of 106 posts scraped
# 100 of 106 posts scraped
# 101 of 106 posts scraped
# 102 of 106 posts scraped
# 103 of 106 posts scraped
# 104 of 106 posts scraped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-360-81d25a1ccdb1> in <module>
# ----> 1 title, price, neighborhood, attributes, description, city = craigslist_motorcycle_scraper(city_list)
#
# <ipython-input-359-068b7e0951a9> in craigslist_motorcycle_scraper(city_list)
#      78                 city_names_.append(city)
#      79
# ---> 80                 time.sleep(random.randint(2,3))
#      81                 count += 1
#      82                 print("{} of {} posts scraped".format(count, results_total))
#
# KeyboardInterrupt:

# %%
description
# Out:
# [[<section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://auburn.craigslist.org/mcy/d/auburn-university-2016-honda-cbr300r/7120429265.html"></div>
#   </div>
#   2016 Honda CBR300r<br/>
#   6,186 miles as of listing<br/>
#   after market: fender eliminator kit and bubble windscreen<br/>
#   I have the original parts if you would prefer those.<br/>
#   clean title<br/>
#   <br/>
#   This is an excellent starter bike or daily commuter. 50+ mpg around auburn and the best parking on campus!<br/>
#   <br/>
#   Not looking to trade<br/>
#   <br/>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://auburn.craigslist.org/mcd/d/fayetteville-bad-credit-no-credit-ok-we/7119776172.html"></div>
#   </div>
#   WE SHIP NATIONWIDE, FINANCE NATIONWIDE! YOU SEE IT! WE SHIP IT! NO PROBLEM!<br/>
#   <br/>
#   FINANCING AVAILABLE. WE CAN GET ALMOST EVERYONE ON A MOTORCYCLE. COME SEE OUR EXPERIENCED AND TRUSTED FINANCE TEAM WHO WILL WORK WITH YOU REGARDLESS OF CREDIT TO MAKE YOU HAPPY.<br/>
#   <br/>
#   FLIP MY CYCLE ONLINE IS A GREAT PLACE TO START TO LOOK.<br/>
#   <br/>
#   Slow pay, bad credit, no credit, divorce, bankruptcy, judgement, past repos and first time buyers.<br/>
#   Have you been turned down before? We can get you riding. We have many lenders that can help you rebuild your credit. We have many finance options available from zero down to minimal down payments. You can apply on line at Flip My Cycle. We are located at 560 N Reilly Road, Fayetteville, NC 28303. WE WELCOME ALL CUSTOMERS REGARDLESS OF THEIR CREDIT SCORE.<br/>
#   <br/>
</section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://auburn.craigslist.org/mcy/d/auburn-2006-honda-xr650l-price-drop/7114333691.html"></div>
#   </div>
#   2006 Honda XR650L <br/>
#   <br/>
#   8,000 miles. This number will go up daily<br/>
#   Acerbis long range gas tank (stock tank included w/ wind flares)<br/>
#   ProTaper SE bars<br/>
#   Fmf exhaust + muffler<br/>
#   Aftermarket skid plate <br/>
#   New gripper seat<br/>
#   50/50 dual-sport tires with 800 mi on bike<br/>
#   New dirt tires included (pictured)<br/>
#   Oil/oil filter changed 200 miles ago<br/>
#   Carb cleaned 100 miles ago<br/>
#   Comes with a backup CDI unit<br/>
#   <br/>
#   This bike starts and rides incredibly. The only negatives are a broken rear blinker and some scratches from trail riding. I ride this bike to work everyday with no problem cruising around 70 mph and ride it on tough single track on the weekends. The XR can really do it all<br/>
#   <br/>
#   Just reduced price to $3800. No trades. Clean title.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://auburn.craigslist.org/mcy/d/auburn-2016-harley-davidson-roadster/7114312352.html"></div>
#   </div>
#   2016 Harley-Davidson Sportster Roadster (EVO 1202cc) in excellent condition for sale $6,999 OBO.<br/>
#   <br/>
#   6,200 miles. Clean title in hand. <br/>
#   <br/>
#   Bike runs and rides well with no issues. Everything works. Relatively low miles, with tires and exterior both in good shape (see pictures). <br/>
#   <br/>
#   I am the only owner and can verify that all recommended services have been done at the dealership.  Recently replaced oxygen sensor and battery.<br/>
#   <br/>
#   Extras/Add-ons:<br/>
#   Harley-Davidson Factory Security System<br/>
#   Upgraded LCD speedometer display with fuel sensor<br/>
#   Upgraded horn<br/>
#   Cell phone mount<br/>
#   Flush fuel tank cap (chrome)<br/>
#   <br/>
#   I really love this bike and am sad to sell it. The only reason I'm doing so is to improve my financial situation. The bike is beautiful and an absolute joy to ride.<br/>
#   <br/>
#   Please feel free to contact me for any questions.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://auburn.craigslist.org/mcy/d/opelika-2017-concours-1400/7111191074.html"></div>
#   </div>
#   Nothing wrong with it.I just don't ride anymore.It is very fast.It has only around 6,200 miles on it.It has heated motorcycle grips with thermostate adjustment,electric windshield and detachable bags with a turn of the key.    </section>],
#  [<section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-2011-yamaha-fz6r/7121632547.html"></div>
#   </div>
#   An excellent example of the best color combination of this bike. Nearly showroom perfect - never wrecked or repaired. Recently serviced and in excellent condition. Super-smooth 4-cylinder 600cc motorcycle. Light, nimble and very powerful. This version of the 600cc Yamaha line has better throttle mapping that makes power delivery much more linear, without any unexpected peaks or dead spots in the power curve. Very easy to drive and great looking - I get compliments everywhere I go. The higher handlebars mean no laying on the fuel tank and a more upright and comfortable ride. Very low to the ground. I have a 30" inseam and can put both feet almost flat on the ground. <br/>
#   <br/>
#      All original with two exceptions. Firstly, and most obviously, is the phone holder on the handlebar - very sturdy and easy to use. Secondly, and less obvious, is a gear change. The front drive sprocket was enlarged by 1 tooth to allow for more spacing between the gears, meaning less shifting as you could hold each gear longer. This effectively improves fuel mileage and top speed (though I haven't tested that).<br/>
#   <br/>
#      Great fuel mileage, fantastic performance and an all-around looker. Can you ask for a better combination? Mileage may go up as I might ride it a little more but I am selling to get a bigger bike. Riding season is fast approaching, don't get caught on a lesser machine. No texts - calls only!    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d
section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/tuscaloosa-2010-harley-davidson-electra/7108990692.html"></div>
#   </div>
#   2010 Harley Davidson Electra Glide Ultra Classic with 38k Miles. 96 Cubic Inch Engine with 6 Speed Overdrive Transmission. Screaming Eagle Stage One Upgrade with Exhaust and Fuel Pak. Absolutely beautiful bike that is senior Adult Owned and Garage Kept. Road Ready. Price is FIRM. I will not respond to text messages. Don’t waste your time texting me. This is a Cash Sale only. 205-799-5596<br/>
#   <br/>
#   NO TEXT<br/>
#   NO SHIPPING <br/>
#   NO AGENTS <br/>
#   NO BS<br/>
#   NO CHECKS<br/>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-zx14/7120583865.html"></div>
#   </div>
#   I have a 2006 ninja ZX14 for sale.. engine internals are from 2008<br/>
#   Not a beginner's bike!!! Very strong and fast engine.. <br/>
#   Upgrades: hid headlights, LED lights, 12 over stretched swingarm, pc3 with aftermarket exhaust..<br/>
#   Plastics are in decent shape, never dropped call/text me if you're interested.. clean title in hand and I also will throw in a spare parts bike as well<br/>
#   Two oh 5 three 08-3801.. Thanks and serious inquiries only    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-2010-kawasaki-zx-6r-for-sale/7120485211.html"></div>
#   </div>
#   I have a 2010 Kawasaki zx 6r for sale. It doesn't have any mechanical issues,runs great,no body damages, and never been laid down. Has a couple of aftermarket parts and has around 9k miles. <br/>
#   <br/>
#   Feel free to contact me at (205) 541-7388.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcd/d/athens-2014-harley-davidson-tri-glide/7120452601.html"></div>
#   </div>
#   2014 Harley-Davidson Tri Glide <br/>
#   Vin# 1HD1MAL16EB851071<br/>
#   44,274 Miles<br/>
#   Blackened Cayenne Sunglow<br/>
#   Highway Pegs<br/>
#   Bluetooth and Navigation Radio<br/>
#   NEVER A DEALER ADD ON FEE <br/>
#   18,900 Plus Tax And Title <br/>
#   For More Information Call <br/>
#   25six // 43one // 917six <br/>
#   Located in Athens Alabama <br/>
#   <br/>
#   See Our Complete Inventory On Our Facebook Page @<br/>
#   KEN BATES AUTO SALES INC<br/>
#   <br/>
#   Stock# 20557    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://huntsville.craigslist.org/mcd/d/athens-2014-harley-davidson-tri-glide/7120451809.html"></div>
#   </div>
#   2014 Harley-Davidson Tri Glide <br/>
#   Vin# 1HD1MAL16EB851071<br/>
#   44,274 Miles<br/>
#   Blackened Cayenne Sunglow<br/>
#   Highway Pegs<br/>
#   Bluetooth and Navigation Radio<br/>
#   NEVER A DEALER ADD ON FEE <br/>
#   18,900.00 Plus Tax And Title <br/>
#   For More Information Call <br/>
#   25six // 43one // 917six <br/>
#   Located in Athens Alabama <br/>
#   <br/>
#   See Our Complete Inventory On Our Facebook Page @<br/>
#   KEN BATES AUTO SALES INC<br/>
#   <br/>
#   Stock# 20557    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-bmw-k1600-gtl-excellent/7120412452.html"></div>
#   </div>
#   BMW K1600 GTL (MY 2014)<br/>
#   22,000 miles<br/>
#   <br/>
#   Engine	6-ZYL<br/>
#   Displ.	1.6<br/>
#   Power	118kw / 160hp<br/>
#   Color	Darkgraphit metallic<br/>
#   <br/>
#   Excellent condition.<br/>
#   No scratches.<br/>
#   Clean title in hand.<br/>
#   <br/>
#   Options:<br/>
#   792	        Seat Bench, High<br/>
#   S430	Safety Pack<br/>
#   S417	Central Locking System<br/>
#   S431	Equipment Package 1<br/>
#   S416	ESA<br/>
#   S603	Alarm System<br/>
#   S530	RDC<br/>
#   S376	BMW US Radio<br/>
#   S138	LED Additional Headlight<br/>
#   S182	DTC<br/>
#   S143	Bluetooth Interface<br/>
#   S134	Adaptive Headlights    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcd/d/birmingham-2017-suzuki-gsx-r750-u01909/7120303685.html"></div>
#   </div>
#   <p>Phone: 678-263-7545</p>
#   <h3>2017 Suzuki GSX-R750 (U01909)</h3>
#   <p>Use the following link to view more information about this vehicle:
#   	<br/><b><u>https://www.mmslithiasprings.com/lc/8770352</u></b></p>
#   <p>Call Shae or Zach at 678-263-7545!<br/>
#   <br/>
#   Hundreds of vehicles in stock. Over 96% approval rating with cash down.</p>
#   <p><h3>2017 Suzuki GSX-R750</h3><p>Three decades ago Suzuki revolutionized sport bikes with the introduction of the GSX-R750. Ever since then, the GSX-R750 has remained true to its original concept and championship-winning heritage. On the road or on the track, the GSX-R750 delivers a breathtaking combination of outstanding engine performance, crisp handling, compact size and light weight. Its secret is an unequaled pairing of 750cc performance with the lightweight, compact chassis of a 600cc Supersport, complemented by technologically advanced suspension front and rear. Try a GSX-R750 and you’ll quickly realize this motorcycle defines performance riding from the center of the sportbike class.</p><p>Built to own the racetrack and let loose on the streets. Since 1985, the GSX-R has been continuously refined to deliver new levels of performance and agility. This legacy of innovation continues with over 1 million legends made</p><p><strong>Features may include:</strong></p><strong>ENGINE</strong><ul><li>	Compact 750cc 4-cylinder engine with a race-proven over-square bore/stroke ratio that produces remarkably strong high RPM power delivery.</li></ul><ul><li>The energy efficient engine employs forged pistons, shot-peened connecting rods, chrome-nitride-coated upper compression and oil control rings, and pentagonal ventilation holes to reduce frictional and mechanical losses.</li></ul><ul><li>Suzuki Dual Throttle Valve (SDTV) fuel injection uses eight, fine-spray 8-hole injectors for improved fuel atomization, which contributes to more complete combustion.</li></ul><ul><li>An Engine Control Module (ECM) provides state-of-the-art engine management and has enhanced settings to suit the intake and exhaust systems, resulting in better fuel economy and linear throttle response.</li></ul><ul><li>Advanced, MotoGP-developed transistorized ignition control programming helps maintain more precise spark timing across the range of engine speed and temperature range.</li></ul><strong>CHASSIS</strong><ul><li>Lightweight and compact twin-spar aluminum-alloy frame is constructed of five cast sections to produce a balance of light weight and strength.</li></ul><ul><li>The frame is mated with a cast aluminum swingarm and multi-piece rear sub-frame that’s ready for race-track adaptation.</li></ul><ul><li>Race-developed, lightweight SHOWA Big Piston front Forks (BPF) deliver superb feedback and consistent performance. Spring preload, rebound and compression damping are all fully adjustable.</li></ul>Single SHOWA rear shock features externally adjustable rebound and compression damping, along with adjustable ride height.<ul><li>Electronically controlled steering damper provides lighter steering at slower speeds and more damping force at racetrack and highway speeds.</li>SUSPENSION<ul><li>Stylized Suzuki “S” 3-D emblems on the fuel tank and the fork upper bracket denotes the quality, sophistication and performance legacy of the brand.</li></ul><ul><li>Optional single seat cowl can replace the passenger seat for an even more aggressive look or for use on solo rides, or track days.</li></ul><ul><li>A variety of Genuine Suzuki Accessories for GSX-R owners are available including a large selection of Suzuki logo apparel.</li></ul><ul><li>12-month limited warranty.</li></ul></ul></p>
#   <h3>Vehicle Details</h3>
#   <hr/>
#   <p>
#
#   Year: 2017<br/>
#
#
#
#   Make: Suzuki<br/>
#
#
#
#   Model: GSX-R750<br/>
#
#
#
#   Mileage: 2625 mi<br/>
#
#
#
#   Stock #: U01909<br/>
#
#
#
#   VIN: JS1GR7MA6H2101909<br/>
#   </p>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/lynnville-harley-davidson-street-glide/7120104629.html"></div>
#   </div>
#   This is a very nice 2008 Harley-Davidson Electra Glide set up like a Street Glide with only 40k miles. 96 cu in motor. 6 speed. 2010 Street Glide exhaust. Has all Street Glide options and more including: Cruise control, Pioneer stereo, lowering kit, HD low profile seat, oil pressure gauge, 12" mini apes with braided lines, chrome(switch buttons, console, dash cover, light bezels, horn cover, voltage reg cover, point cover) and more. $7500. Clear title in hand. NO TRADES!! 931-619-9300    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-indian-scout/7119476625.html"></div>
#   </div>
#   This is really for someone wanting a new bike for a $4500 discount. The chrome pipes and heat shield are new in box; the additional intake is new; the extra seat is new; so you could go from blacked out to chrome and tan. Also included is the windshield ($395); helmet ($80); Bluetooth Cardo audio system ($189); AND I have a transferable Diamond Care Package covering all maintenance, parts and labor for three years.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-2004-ducati-1000ds/7119285639.html"></div>
#   </div>
#   2004 Ducati 1000DS Multistrada <br/>
#   4000 miles <br/>
#   Red<br/>
#   Sargent seat <br/>
#   Front and rear Pit Bull stands<br/>
#   <br/>
#   Text inquiries to 205-441-5214    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/lynnville-2006-harley-davidson-heritage/7119156060.html"></div>
#   </div>
#   This is a very nice 2006 Harley-Davidson Heritage Softail with only 39k miles. Has over $2000 in extras including: Stage 1 kit with Vance and Hines Staggered Shots exhaust, chrome( master cylinder, switch housings, clutch perch, levers, sprocket cover, derby cover and more), Daymaker LED headlight. Starts, runs and rides better than new. Clear title in hand. $5500. NO TRADES! 931-619-9300    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-2015-honda-pcx-150-cc/7118949029.html"></div>
#   </div>
#   Very low miles.  Like new, but, for a narrow scrape on one side. Less than 800 miles. Great value. Stylish, Fun, reliable and economical transportation.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcd/d/muscadine-2015-harley-davidson-street/7118941256.html"></div>
#   </div>
#   2015 Harley Davidson Street XG500 with only 12128 miles. This Harley runs and drives great. Small crack in the seat.<br/>
#   <br/>
#   Located in Muscadine, AL about an hour from Atlanta just off I-20. NO CALLS OR TEXT AFTER 10:00 PM EASTERN TIME .<br/>
#   I do not do any financing. May do some trading. If wanting to trade something please email or text what you have. Please know the real trade in value of yours. I am not interested in anything at KBB retail value. Thanks    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-agv-k3-helmet-nib/7118886158.html"></div>
#   </div>
#   AGV helmet is new in box never worn. Size Small<br/>
#   $100 compare at $229    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/m
section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/trussville-2019-bmw-r1250gs/7118064897.html"></div>
#   </div>
#   2019 BMW R1250GS Cosmic blue in perfect, showroom condition.  Premium Edition with Comfort package, Touring Package, Dynamic Package, LED lights and Cross spoke wheels. Original owner; Clear title in hand.  Over $25,000 invested and barely broken in.<br/>
#   <br/>
#   Bought in August of 2019, but I just don't have time to ride it and have other things I need.  In my opinion, this is truly the finest motorcycle made today.  Has remainder of BMW 3 year warranty.<br/>
#   <br/>
#   Heated Grips, tire pressure monitoring system, dynamic stability control, dynamic traction control with ride modes, electronic cruise control, ABS, gear shift assist pro, keyless start, adjust on the fly windshield, adjustable seats, digital screen dash with information center and adjustments.<br/>
#   Also has BMW navigator, BMW Vario panniers and top case with back pad, comfort grips, Tourtech engine guards.  will come with Denali DR1 aux lights and B6 brake surround with canbus module (new in box) and Scorpion AT950 modular helmet with speakers installed<br/>
#   <br/>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-2010-harley-davidson/7118042101.html"></div>
#   </div>
#   2010 Harley Davidson Heritage Softail Classic. Garage kept, showroom condition. Actual mileage 8608 miles. Vance and Hines "Long Shot" pipes with Stage 2 tuning. Includes Harley Davidson weather proof jacket, leather cold weather gloves, Harley Davidson helmet with visor, and more. See at 116 Hilltop Business Center in Pelham, AL. Call 205-534-0331 for more information. $12,500.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/mobile-1999-harley-fxr3-fxr/7117951686.html"></div>
#   </div>
#   beautiful 99 fxr3 in very rare blue flame. this bike is unmolested just as it came off the factory floor. beautiful paint small beach scene air brushed on tip of front fender looks nice. runs and shifts perfect. some minor pitting on chrome pieces but overall in great condition. one of the rarest and the first cvo harley and this is your chance to own one. call john in daphne alabama at 251 367 426four. we can help you arrange shipping.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d/birmingham-triumph-bonneville-1971-t120/7117759392.html"></div>
#   </div>
#   This is a Frame up Restoration. Runs as it should and sounds great.<br/>
#   <br/>
#   https://www.youtube.com/watch?v=sPyrKb0Iwac     "Use Headphones"<br/>
#   <br/>
#   I am posting the Build list below so read thoroughly.<br/>
#   Selling for $6200.00 <br/>
#   No Checks. No Shipping. No Joyrides Cash Money in hand.<br/>
#   Call 205-540-7556 <br/>
#   <br/>
#   1. New Correct Tires, Tubes, Rim Strips.<br/>
#   2. New Wheels, and Stainless Steel Spokes.<br/>
#   3. New Cables for Clutch, Brakes, Throttles, Tach, and Speedometer.<br/>
#   4. Gas tank has been professionally cleaned and coated with Por15 Epoxy.<br/>
#   5. Fuel petcocks are new, Carbs have the newer StayUp floats.<br/>
#   6. New Superthick neverleak Fork Seals.<br/>
#   7. New Coils and Electronic Ignition.<br/>
#   8. Ignition also has switchable Battery Eliminator, If you want to run that way.<br/>
#   9. New Gel Battery.<br/>
#   10. New Seat is lower than the too tall original.<br/>
#   11. Piston rings are New and Valves Ground Fresh.<br/>
#   12. New Handlebars, Headlamp Assy, Tail Lense, and Signal Lenses.<br/>
#   13. All Engine Seals are new Engine Gaskets are new.<br/>
#   14. All receipts availible but I keep them for future vendor reference.<br/>
#   <br/>
#   15. New Extended Leverage Front Brake Arms at the Drum "Not Shown" But makes a huge difference in Front brakE Effort and effectiveness. New Front Brake metalic Shoes<br/>
#   <br/>
#    It had 6700 miles on it when I bought it and now since the restoration it shows 7002 miles.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://bham.craigslist.org/mcy/d
    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/dothan-2010-harley-davidson-heritage/7115959257.html"></div>
#   </div>
#   2010 Harley Heritage Softail Classic<br/>
#   96 ci engine<br/>
#   6 speed transmission<br/>
#   <br/>
#   Add-ons:<br/>
#   Vance and hines slip on mufflers (a little louder than stock)<br/>
#   Aftermarket Grips<br/>
#   Sissy bar luggage rack with led light<br/>
#   <br/>
#   My father bought this bike in may 2012 from a guy in the army that bought it in germany and had it brought over here. Tires are good, brakes are good, maintenance is good (ive done the maintenance), Battery is good. This bike is beautiful and needs nothing. Asking $10,500. No trades. Do not need help selling. Text or call.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/dothan-drz400e/7115876184.html"></div>
#   </div>
#   <br/>
#   2000 Suzuki DRZ400E <br/>
#   Aftermarket lights/headlight<br/>
#   MRD full exhaust<br/>
#   FCR carb with JD jet kit<br/>
#   Bead locks<br/>
#   Newer chain/Sprockets<br/>
#   Newer wheel bearings <br/>
#   Tires are good<br/>
#   Clarke Fuel tank<br/>
#   Seat Concepts low seat<br/>
#   Luggage rack<br/>
#   Suspension rebuilt and revalved/resprung by Cogent Dynamics<br/>
#   <br/>
#   Located in Dothan, AL<br/>
#   $4500<br/>
#   <br/>
#   <br/>
#   <br/>
#   Tags:<br/>
#   Drz drz400 dualsport dual sport road legal street legal street legal dirtbike 400 450 trail<br/>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/dothan-03-buell-lightning/7115872076.html"></div>
#   </div>
#   03 Buell XB9S<br/>
#   30574 miles and going up continuing to ride<br/>
#   Doesn’t leak or smoke. <br/>
#   Doesn’t use oil even on the highway. <br/>
#   All of the “fix it or the world will end “ mods have been done already <br/>
#   Sounds amazing and has boatloads of low end torque.<br/>
#   <br/>
#   Has the following Mods upgrades:<br/>
#   - Jardine slip on(freshly repacked)<br/>
#   - Race tune from IDS<br/>
#   - K&amp;N air filter<br/>
#   - Rizoma mirrors<br/>
#   - Smoked timing cover with red LEDs behind it<br/>
#   - Updated Bronze oil pump drive gear <br/>
#   - Buell saddle bags<br/>
#   - Right Side Scoop from comfort kit<br/>
#   - 04-up style drive belt(stronger)<br/>
#   - Comfort seat<br/>
#   <br/>
#   <br/>
#   Recent work:<br/>
#   - Replaced original engine with 14k mile engine after I found chips in oil. Regasketed/sealed with cometic gaskets and HD gaskets.<br/>
#   - New rear wheel bearings<br/>
#   - Newer Metzler Sportec tires<br/>
#   - Reflective heat tape applied inside of frame<br/>
#   - Forks rebuilt with new bushings and seals. New Factory fork oil fill and tubes were polished also.<br/>
#   - Crank nut torque updated to new specs<br/>
#   - Oil change. Mobile 15w50 in crank case, formula + in primary <br/>
#   - New front brake pads <br/>
#   - Brake fluid flushed with fresh DOT4<br/>
#   - Headers polished<br/>
#   <br/>
#   <br/>
#   Included/not installed:<br/>
#   - old engine <br/>
#   - Original wheels<br/>
#   - New Stark fuel pump kit<br/>
#   - Stock muffler<br/>
#   - Box of random parts<br/>
#   <br/>
#   <br/>
#   <br/>
#   Tags: Buell xb xb9 xb9s 1000 naked nakedbike street fighter streetfighter custom loud rare liter<br/>
#   </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/hartford-2017-street-glide-special/7114485912.html"></div>
#   </div>
#   2017 Street Glide Special 3600 miles S&amp;S intake $20,000.00 OBO! Financing available!    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/dothan-harley-davidson/7114031709.html"></div>
#   </div>
#   2009 Harley Davidson <br/>
#   Rocker C FXCWC<br/>
#   9300 miles<br/>
#   Soft tail with single and double seats, windshield (removable), excellent condition!<br/>
#   Will trade for a Jeep or Can Am Spyder!!!!    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/dothan-motorcycle/7112155870.html"></div>
#   </div>
#   2008 Yamaha 1300 vstar tourer. $4000.00 . New back tire.New battery and forks freshly serviced. Fresh oil service. Ready to ride anywhere. Strong beautiful bike. Clean title. No trade. Call Greg 3347965361    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/fort-rucker-honda-vtx-1300/7110766246.html"></div>
#   </div>
#   This amazing bike has had no issues for the years that I’ve had it. Selling due to moving and not frequently riding it. Mostly been in storage and well taken care of it. A fresh set of tires to ride you off into the sunset and plenty of miles to go on the rest of the body. Get this great bike while the sale lasts.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/enterprise-1978-harley-wide-glide/7109918395.html"></div>
#   </div>
#   1978 Harley Wide Glide Custom. Just serviced. Ready to ride. $10000   334-313-7295  8am to 8pm Perry    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/enterprise-1980-harley-low-rider/7109916113.html"></div>
#   </div>
#   1980 Stock Harley Lowrider.   Just serviced at local Harley shop.  Ready to ride  $10000 obo.  334-313-7295.  9am to 8pm.    </section>,
#   <section id="postingbody">
#   <div class="print-information print-qrcode-container">
#   <p class="print-qrcode-label">QR Code Link to This Post</p>
#   <div class="print-qrcode" data-location="https://dothan.craigslist.org/mcy/d/enterprise-2016-vulcan-cafe/7106995830.html"></div>
#   </div>
#   1 owner bike Title in hand, 3,639 miles on the odometer but will go up slightly as I ride it once a week. 650cc sport cruiser (same engine that’s on the Ninja 650 NOT the ZX-6R) Very quick. I average 53-55 mpg./3.7 gallon tank. I usually run it 140-150 miles before I break out a big whopping $6 to fill it up. The tach is analog with a redline at 9.5K the digital speedometer shows a fuel gauge, odometer, trip A &amp; B, current mpg, average mpg, range until empty and clock function. It has a Delkevic 16” slash cut round ceramic coated full exhaust installed. It is loud and distinctive, people will know when it is you riding up. There is a small lockable box behind the license plate to store registration and proof of insurance paperwork. black and green bar end weights, black and green short throw clutch and break levers and black and green swing arm spools for maintenance stands as shown in the pics. I still have the stock parts if you want them (except for the exhaust). I will also include an extra oil filter, universal swing arm stand, waterproof bike cover, a Joe Rocket Rapid Transit tank bag with backpack straps, a black and green leather Joe Rocket jacket with removable insulation, a low profile DOT approved helmet, Wiley X gloves and a pair of Oakley red iridium Jupiter II sunglasses I used when I rode. No test rides without cash in hand.    </section>]]

# %%
            # open the motorcycles page in a city page 
#             for motorcycles_link in city_soup.find_all('a', class_ = 'mca'):


#                 moto_link = motorcycles_link['href']
#                 moto_page = requests.get(moto_link)
#                 moto_soup = BeautifulSoup(moto_page.text, 'html.parser')
#                 print('in city')
                # open the motorcycle listings in the motorcycles page 
    #             for motorcycle_listing in moto_soup.find_all('a', class_ = 'result-title hdrlnk'):

    #                 moto_listing = motorcycles_listing['href']
    #                 list_page = requests.get(moto_listing)
    #                 list_soup = BeautifulSoup(list_page.text, 'html.parser')
    #                 #find the total number of posts to find the limit for each page
    #                 results_num = html_soup.find('div', class_= 'search-legend')
    #                 #pulled the total count of posts as the upper bound of the pages array
    #                 results_total = int(results_num.find('span', class_='totalcount').text) 
    #                 #each page has 119 posts so each new page is defined as follows: s=120, s=240, s=360, and so on. So we need to step in size 120 in the np.arange function
    #                 pages = np.arange(0, results_total+1, 120)

    #                 iterations = 0
    #                 print('motorcycle listings')
    #                 for page in pages:         
    #                     #get request
    #                     response = requests.get("https://{}.craigslist.org/search/mca?".format(city) 
    #                                    + "s=" #the parameter for defining the page number 
    #                                    + str(page) #the page number in the pages array from earlier
    #                                    + "&bundleDuplicates=1")

    #                     time.sleep(random.randint(5,10))

    #                     #throw warning for status codes that are not 200
    #                     if response.status_code != 200:
    #                         warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #                     #define the html text
    #                     page_html = BeautifulSoup(response.text, 'html.parser')

    #                     #define the posts
    #                     posts = page_html.find_all('li', class_= 'result-row')

    #                     #extract data by item
    #                     for post in page_html.find_all('a', class_='result-title hdrlnk'):

    #                         moto_link = post['href']
    #                         moto_page = requests.get(moto_link)
    #                         moto_soup = BeautifulSoup(moto_page.text, 'html.parser')

    #                         title = moto_soup.find('span', id = 'titletextonly').text
    #                         price = moto_soup.find('span', class_ = 'price').text
    #                         neighborhood = moto_soup.find('small').text
    #                         attributes = moto_soup.find_all('p', attrs = {'class': 'attrgroup'})
    #                         description = moto_soup.find('section', id = 'postingbody').text
    #                         print(title, 'in in in')


    # ----------------------------------------------------------------------------






    #     for city in city_names:

    #         #get the first page of the Austin motorcycle prices
    #         response = requests.get('https://{}.craigslist.org/search/mca?s=0&bundleDuplicates=1'.format(city))
    #         #parse through it and make it readable
    #         html_soup = BeautifulSoup(response.text, 'html.parser')
    #         #find the total number of posts to find the limit for each page
    #         results_num = html_soup.find('div', class_= 'search-legend')
    #         #pulled the total count of posts as the upper bound of the pages array
    #         results_total = int(results_num.find('span', class_='totalcount').text) 
    #         #each page has 119 posts so each new page is defined as follows: s=120, s=240, s=360, and so on. So we need to step in size 120 in the np.arange function
    #         pages = np.arange(0, results_total+1, 120)
    #         print("{} Pages = {}".format(city.title(), len(pages)))

    #         iterations = 0

    #         post_timing = []
    #         post_hoods = []
    #         post_title_texts = []
    #         post_links = []
    #         post_prices = []
    #         city_names = []

    #         for page in pages:         
    #             #get request
    #             response = requests.get("https://{}.craigslist.org/search/mca?".format(city) 
    #                            + "s=" #the parameter for defining the page number 
    #                            + str(page) #the page number in the pages array from earlier
    #                            + "&bundleDuplicates=1")

    #             time.sleep(random.randint(5,10))

    #             #throw warning for status codes that are not 200
    #             if response.status_code != 200:
    #                 warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #             #define the html text
    #             page_html = BeautifulSoup(response.text, 'html.parser')

    #             #define the posts
    #             posts = html_soup.find_all('li', class_= 'result-row')

    #             #extract data by item
    #             for post in posts:

    #                 if post.find('span', class_ = 'result-hood') is not None:

    #                     #posting date
    #                     #grab the datetime element 0 for date and 1 for time
    #                     post_datetime = post.find('time', class_= 'result-date')['datetime']
    #                     post_timing.append(post_datetime)

    #                     #neighborhoods
    #                     post_hood = post.find('span', class_= 'result-hood').text
    #                     post_hoods.append(post_hood)

    #                     #title text
    #                     post_title = post.find('a', class_='result-title hdrlnk')
    #                     post_title_text = post_title.text
    #                     post_title_texts.append(post_title_text)

    #                     #post link
    #                     post_link = post_title['href']
    #                     post_links.append(post_link)

    #                     #removes the \n whitespace from each side, removes the currency symbol, and turns it into an int
    #                     post_price = (post.a.text.strip().replace("$", "")) 
    #                     post_prices.append(post_price)

    #                     #add the city's name to the row
    #                     city_names.append(city)

    #             iterations += 1
    #             print("{} Page ".format(city.title()) + str(iterations) + " of {} pages".format(len(pages)) + " scraped successfully!")
    #             print(len(post_links))

    #         print("\n")

    #         print("{} complete!".format(city.title()))
    #         print(str(len(post_links)) + " rows collected.")

    #     #     return (post_timing, post_hoods, post_title_texts, post_links, post_prices, city_names)

    #     print("\n")

    #     print("Srape complete!")
    #     print(len(post_links))

    #     moto = pd.DataFrame({'posted': post_timing,
    #                         'neighborhood': post_hoods,
    #                         'post title': post_title_texts,
    #                         'URL': post_links,
    #                         'price': post_prices,
    #                         'city': city_names})

    #     moto = moto.drop_duplicates(subset='URL')
    #     len(moto.drop_duplicates(subset='URL'))

    #     for idx, _ in enumerate(moto['price']):
    #         if _ == '':
    #             moto = moto.drop(idx)
    #         else:
    #             pass

    #     # make the price a float
    #     moto['price'] = moto['price'].apply(lambda x: float(x))

    #     # convert datetime string into datetime object to be able to work with it
    #     from datetime import datetime
    #     moto['posted'] = pd.to_datetime(moto['posted'])

    #     # remove the parenthesis from the left and right of the neighborhoods
    #     moto['neighborhood'] = moto['neighborhood'].map(lambda x: x.lstrip('(').rstrip(')'))

    #     #fix one-offs
    #     moto['city'].replace('sfbay', 'San Francisco', inplace=True)
    #     moto['city'].replace('losangeles', 'Los Angeles', inplace=True)
    #     moto['city'].replace('oklahomacity', 'Oklahoma City', inplace=True)
    #     moto['city'].replace('newyork', 'New York City', inplace=True)
    #     moto['city'].replace('neworleans', 'New Orleans', inplace=True)

    #     # titlecase them 
    #     moto['neighborhood'] = moto['neighborhood'].str.title()
    #     moto['city'] = o['city'].str.title()

    #     # just take the first name of the neighborhood list, splitting on the '/' delimiter
    #     moto['neighborhood'] = moto['neighborhood'].apply(lambda x: x.split('/')[0])

    #     # remove whitespaces
    #     moto['neighborhood'] = moto['neighborhood'].apply(lambda x: x.strip())

    #     # save the clean data
    #     moto.to_csv("craigslist_motorcycles_7APR2020.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-769f45117264> in <module>
# ----> 1 for city in box.find_all('li', a = 'href'):
#       2     print('open_cities')
#       3
#       4     city_link = city['href']
#       5     city_page = requests.get(city_link)
#
# NameError: name 'box' is not defined
